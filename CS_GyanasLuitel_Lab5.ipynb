# %% [markdown]
# # Chapter 5 : Classification – Detecting Poor Answers

# %% [markdown]
# <ul>
#     <li>Name: Gyanas Luitel</li>
#     <li>Group: Computer Science</li>
#     <li>Roll No: 27</li>
#
# </ul>

# %% [markdown]
# ### Importing

# %%
from matplotlib import pylab
import numpy as np
import os
from scipy.stats import norm
from matplotlib import pyplot

# %%
import sys
import re

try:
    import ujson as json  # UltraJSON if available
except:
    import json
    
from dateutil import parser as dateparser

from operator import itemgetter
from xml.etree import cElementTree as etree
from collections import defaultdict, Mapping, Counter
# Out:
# <ipython-input-2-bac4f6a61535>:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#   from collections import defaultdict, Mapping, Counter

# %% [markdown]
# ## Fetching the data

# %%
DATA_DIR="./Lab5/data"

#filename = os.path.join(DATA_DIR, "posts-2011-12.xml")
filename = os.path.join(DATA_DIR, "Posts.xml")
print(f"Reading from xml {filename}")
filename_filtered = os.path.join(DATA_DIR, "filtered.tsv")
print(f"Filtered: {filename_filtered}")
filename_filtered_meta = os.path.join(DATA_DIR, "filtered-meta.json")
print(f"Meta: {filename_filtered_meta}")

q_creation = {}  # creation datetimes of questions
q_accepted = {}  # id of accepted answer

# question -> [(answer Id, IsAccepted, TimeToAnswer, Score), ...]
meta = defaultdict(list)
# Out:
# Reading from xml ./Lab5/data/Posts.xml
# Filtered: ./Lab5/data/filtered-meta.tsv
# Meta: ./Lab5/data/filtered-meta.json

# %% [markdown]
# ## Starting with kNN

# %%
from sklearn import neighbors

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=2)
knn
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.fit([[1],[2],[3],[4],[5],[6]], [0,0,0,1,1,1])
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.predict([[1.5]])
# Out:
# array([0])

# %%
knn.predict([[37]])
# Out:
# array([1])

# %%
knn.predict([[3]])
# Out:
# array([0])

# %%
knn.predict_proba([[1.5]])
# Out:
# array([[1., 0.]])

# %%
knn.predict_proba([[37]])
# Out:
# array([[0., 1.]])

# %%
knn.predict_proba([[3.5]])
# Out:
# array([[0.5, 0.5]])

# %% [markdown]
# ### Engineering the features

# %%
# regegx to find code snippets
code_match = re.compile('<pre>(.*?)</pre>', re.MULTILINE | re.DOTALL)
link_match = re.compile(
    '<a href="http://.*?".*?>(.*?)</a>', re.MULTILINE | re.DOTALL)
img_match = re.compile('<img(.*?)/>', re.MULTILINE | re.DOTALL)
tag_match = re.compile('<[^>]*>', re.MULTILINE | re.DOTALL)

# %%
def extract_features_from_body(s):
    link_count_in_code = 0
    # count links in code to later subtract them
    for match_str in code_match.findall(s):
        link_count_in_code += len(link_match.findall(match_str))
    return len(link_match.findall(s)) - link_count_in_code

# %%
def filter_html(s):
    num_code_lines = 0
    link_count_in_code = 0
    code_free_s = s

    num_images = len(img_match.findall(s))

    # remove source code and count how many lines
    for match_str in code_match.findall(s):
        num_code_lines += match_str.count('\n')
        code_free_s = code_match.sub("", code_free_s)

        # sometimes source code contain links, which we don't want to count
        link_count_in_code += len(link_match.findall(match_str))

    links = link_match.findall(s)
    link_count = len(links)

    link_count -= link_count_in_code

    link_free_s = re.sub(
        " +", " ", tag_match.sub('', code_free_s)).replace("\n", "")

    for link in links:
        if link.lower().startswith("http://"):
            link_free_s = link_free_s.replace(link, '')

    num_text_tokens = link_free_s.count(" ")

    return link_free_s, num_text_tokens, num_code_lines, link_count, num_images

# %%
years = defaultdict(int)
num_questions = 0
num_answers = 0

if sys.version_info.major < 3:
    # Python 2, map() returns a list, which will lead to out of memory errors.
    # The following import ensures that the script behaves like being executed
    # with Python 3.
    from itertools import imap as map


def parsexml(filename):
    global num_questions, num_answers

    counter = 0

    it = map(itemgetter(1),
             iter(etree.iterparse(filename, events=('start',))))

    root = next(it)  # get posts element

    for elem in it:
        if counter % 100000 == 0:
            print("Processed %i <row/> elements" % counter)

        counter += 1

        if elem.tag == 'row':
            creation_date = dateparser.parse(elem.get('CreationDate'))

            Id = int(elem.get('Id'))
            PostTypeId = int(elem.get('PostTypeId'))
            Score = int(elem.get('Score'))

            if PostTypeId == 1:
                num_questions += 1
                years[creation_date.year] += 1

                ParentId = -1
                TimeToAnswer = 0
                q_creation[Id] = creation_date
                accepted = elem.get('AcceptedAnswerId')
                if accepted:
                    q_accepted[Id] = int(accepted)
                IsAccepted = 0

            elif PostTypeId == 2:
                num_answers += 1

                ParentId = int(elem.get('ParentId'))
                if not ParentId in q_creation:
                    # question was too far in the past
                    continue

                TimeToAnswer = (creation_date - q_creation[ParentId]).seconds

                if ParentId in q_accepted:
                    IsAccepted = int(q_accepted[ParentId] == Id)
                else:
                    IsAccepted = 0

                meta[ParentId].append((Id, IsAccepted, TimeToAnswer, Score))

            else:
                continue

            Text, NumTextTokens, NumCodeLines, LinkCount, NumImages = filter_html(
                elem.get('Body'))

            values = (Id, ParentId,
                      IsAccepted,
                      TimeToAnswer, Score,
                      Text.encode("utf-8"),
                      NumTextTokens, NumCodeLines, LinkCount, NumImages)

            yield values

            root.clear()  # preserve memory

with open(filename_filtered, "w") as f:
    for values in parsexml(filename):
        line = "\t".join(map(str, values))
        f.write(line + "\n")

with open(filename_filtered_meta, "w") as f:
    json.dump(meta, f)

print("years:", years)
print(f"#qestions: {num_questions}")
print(f"#answers: {num_answers}")
# Out:
# Processed 0 <row/> elements
# Processed 100000 <row/> elements
# Processed 200000 <row/> elements
# Processed 300000 <row/> elements
# Processed 400000 <row/> elements
# Processed 500000 <row/> elements
# Processed 600000 <row/> elements
# Processed 700000 <row/> elements
# Processed 800000 <row/> elements
# Processed 900000 <row/> elements
# Processed 1000000 <row/> elements
# Processed 1100000 <row/> elements
# Processed 1200000 <row/> elements
# Processed 1300000 <row/> elements
# Processed 1400000 <row/> elements
# Processed 1500000 <row/> elements
# Processed 1600000 <row/> elements
# Processed 1700000 <row/> elements
# Processed 1800000 <row/> elements
# Processed 1900000 <row/> elements
# Processed 2000000 <row/> elements
# Processed 2100000 <row/> elements
# Processed 2200000 <row/> elements
# Processed 2300000 <row/> elements
# Processed 2400000 <row/> elements
# Processed 2500000 <row/> elements
# Processed 2600000 <row/> elements
# Processed 2700000 <row/> elements
# Processed 2800000 <row/> elements
# Processed 2900000 <row/> elements
# Processed 3000000 <row/> elements
# Processed 3100000 <row/> elements
# Processed 3200000 <row/> elements
# Processed 3300000 <row/> elements
# Processed 3400000 <row/> elements
# Processed 3500000 <row/> elements
# Processed 3600000 <row/> elements
# Processed 3700000 <row/> elements
# Processed 3800000 <row/> elements
# Processed 3900000 <row/> elements
# Processed 4000000 <row/> elements
# Processed 4100000 <row/> elements
# Processed 4200000 <row/> elements
# Processed 4300000 <row/> elements
# Processed 4400000 <row/> elements
# Processed 4500000 <row/> elements
# Processed 4600000 <row/> elements
# Processed 4700000 <row/> elements
# Processed 4800000 <row/> elements
# Processed 4900000 <row/> elements
# Processed 5000000 <row/> elements
# Processed 5100000 <row/> elements
# Processed 5200000 <row/> elements
# Processed 5300000 <row/> elements
# Processed 5400000 <row/> elements
# Processed 5500000 <row/> elements
# Processed 5600000 <row/> elements
# Processed 5700000 <row/> elements
# Processed 5800000 <row/> elements
# Processed 5900000 <row/> elements
# Processed 6000000 <row/> elements
# Processed 6100000 <row/> elements
# Processed 6200000 <row/> elements
# Processed 6300000 <row/> elements
# Processed 6400000 <row/> elements
# Processed 6500000 <row/> elements
# Processed 6600000 <row/> elements
# Processed 6700000 <row/> elements
# Processed 6800000 <row/> elements
# Processed 6900000 <row/> elements
# Processed 7000000 <row/> elements
# Processed 7100000 <row/> elements
# Processed 7200000 <row/> elements
# Processed 7300000 <row/> elements
# Processed 7400000 <row/> elements
# Processed 7500000 <row/> elements
# Processed 7600000 <row/> elements
# Processed 7700000 <row/> elements
# Processed 7800000 <row/> elements
# Processed 7900000 <row/> elements
# Processed 8000000 <row/> elements
# Processed 8100000 <row/> elements
# Processed 8200000 <row/> elements
# Processed 8300000 <row/> elements
# Processed 8400000 <row/> elements
# Processed 8500000 <row/> elements
# Processed 8600000 <row/> elements
# Processed 8700000 <row/> elements
# Processed 8800000 <row/> elements
# Processed 8900000 <row/> elements
# Processed 9000000 <row/> elements
# Processed 9100000 <row/> elements
# Processed 9200000 <row/> elements
# Processed 9300000 <row/> elements
# Processed 9400000 <row/> elements
# Processed 9500000 <row/> elements
# Processed 9600000 <row/> elements
# Processed 9700000 <row/> elements
# Processed 9800000 <row/> elements
# Processed 9900000 <row/> elements
# Processed 10000000 <row/> elements
# Processed 10100000 <row/> elements
# Processed 10200000 <row/> elements
# Processed 10300000 <row/> elements
# Processed 10400000 <row/> elements
# Processed 10500000 <row/> elements
# Processed 10600000 <row/> elements
# Processed 10700000 <row/> elements
# Processed 10800000 <row/> elements
# Processed 10900000 <row/> elements
# Processed 11000000 <row/> elements
# Processed 11100000 <row/> elements
# Processed 11200000 <row/> elements
# Processed 11300000 <row/> elements
# Processed 11400000 <row/> elements
# Processed 11500000 <row/> elements
# Processed 11600000 <row/> elements
# Processed 11700000 <row/> elements
# Processed 11800000 <row/> elements
# Processed 11900000 <row/> elements
# Processed 12000000 <row/> elements
# Processed 12100000 <row/> elements
# Processed 12200000 <row/> elements
# Processed 12300000 <row/> elements
# Processed 12400000 <row/> elements
# Processed 12500000 <row/> elements
# Processed 12600000 <row/> elements
# Processed 12700000 <row/> elements
# Processed 12800000 <row/> elements
# Processed 12900000 <row/> elements
# Processed 13000000 <row/> elements
# Processed 13100000 <row/> elements
# Processed 13200000 <row/> elements
# Processed 13300000 <row/> elements
# Processed 13400000 <row/> elements
# Processed 13500000 <row/> elements
# Processed 13600000 <row/> elements
# Processed 13700000 <row/> elements
# Processed 13800000 <row/> elements
# Processed 13900000 <row/> elements
# Processed 14000000 <row/> elements
# Processed 14100000 <row/> elements
# Processed 14200000 <row/> elements
# Processed 14300000 <row/> elements
# Processed 14400000 <row/> elements
# Processed 14500000 <row/> elements
# Processed 14600000 <row/> elements
# Processed 14700000 <row/> elements
# Processed 14800000 <row/> elements
# Processed 14900000 <row/> elements
# Processed 15000000 <row/> elements
# Processed 15100000 <row/> elements
# Processed 15200000 <row/> elements
# Processed 15300000 <row/> elements
# Processed 15400000 <row/> elements
# Processed 15500000 <row/> elements
# Processed 15600000 <row/> elements
# Processed 15700000 <row/> elements
# Processed 15800000 <row/> elements
# Processed 15900000 <row/> elements
# Processed 16000000 <row/> elements
# Processed 16100000 <row/> elements
# Processed 16200000 <row/> elements
# Processed 16300000 <row/> elements
# Processed 16400000 <row/> elements
# Processed 16500000 <row/> elements
# Processed 16600000 <row/> elements
# Processed 16700000 <row/> elements
# Processed 16800000 <row/> elements
# Processed 16900000 <row/> elements
# Processed 17000000 <row/> elements
# Processed 17100000 <row/> elements
# Processed 17200000 <row/> elements
# Processed 17300000 <row/> elements
# Processed 17400000 <row/> elements
# Processed 17500000 <row/> elements
# Processed 17600000 <row/> elements
# Processed 17700000 <row/> elements
# Processed 17800000 <row/> elements
# Processed 17900000 <row/> elements
# Processed 18000000 <row/> elements
# Processed 18100000 <row/> elements
# Processed 18200000 <row/> elements
# Processed 18300000 <row/> elements
# Processed 18400000 <row/> elements
# Processed 18500000 <row/> elements
# Processed 18600000 <row/> elements
# Processed 18700000 <row/> elements
# Processed 18800000 <row/> elements
# Processed 18900000 <row/> elements
# Processed 19000000 <row/> elements
# Processed 19100000 <row/> elements
# Processed 19200000 <row/> elements
# Processed 19300000 <row/> elements
# Processed 19400000 <row/> elements
# Processed 19500000 <row/> elements
# Processed 19600000 <row/> elements
# Processed 19700000 <row/> elements
# Processed 19800000 <row/> elements
# Processed 19900000 <row/> elements
# Processed 20000000 <row/> elements
# Processed 20100000 <row/> elements
# Processed 20200000 <row/> elements
# Processed 20300000 <row/> elements
# Processed 20400000 <row/> elements
# Processed 20500000 <row/> elements
# Processed 20600000 <row/> elements
# Processed 20700000 <row/> elements
# Processed 20800000 <row/> elements
# Processed 20900000 <row/> elements
# Processed 21000000 <row/> elements
# Processed 21100000 <row/> elements
# Processed 21200000 <row/> elements
# Processed 21300000 <row/> elements
# Processed 21400000 <row/> elements
# Processed 21500000 <row/> elements
# Processed 21600000 <row/> elements
# Processed 21700000 <row/> elements
# Processed 21800000 <row/> elements
# Processed 21900000 <row/> elements
# Processed 22000000 <row/> elements
# Processed 22100000 <row/> elements
# Processed 22200000 <row/> elements
# Processed 22300000 <row/> elements
# Processed 22400000 <row/> elements
# Processed 22500000 <row/> elements
# Processed 22600000 <row/> elements
# Processed 22700000 <row/> elements
# Processed 22800000 <row/> elements
# Processed 22900000 <row/> elements
# Processed 23000000 <row/> elements
# Processed 23100000 <row/> elements
# Processed 23200000 <row/> elements
# Processed 23300000 <row/> elements
# Processed 23400000 <row/> elements
# Processed 23500000 <row/> elements
# Processed 23600000 <row/> elements
# Processed 23700000 <row/> elements
# Processed 23800000 <row/> elements
# Processed 23900000 <row/> elements
# Processed 24000000 <row/> elements
# Processed 24100000 <row/> elements
# Processed 24200000 <row/> elements
# Processed 24300000 <row/> elements
# Processed 24400000 <row/> elements
# Processed 24500000 <row/> elements
# Processed 24600000 <row/> elements
# Processed 24700000 <row/> elements
# Processed 24800000 <row/> elements
# Processed 24900000 <row/> elements
# Processed 25000000 <row/> elements
# Processed 25100000 <row/> elements
# Processed 25200000 <row/> elements
# Processed 25300000 <row/> elements
# Processed 25400000 <row/> elements
# Processed 25500000 <row/> elements
# Processed 25600000 <row/> elements
# Processed 25700000 <row/> elements
# Processed 25800000 <row/> elements
# Processed 25900000 <row/> elements
# Processed 26000000 <row/> elements
# Processed 26100000 <row/> elements
# Processed 26200000 <row/> elements
# Processed 26300000 <row/> elements
# Processed 26400000 <row/> elements
# Processed 26500000 <row/> elements
# Processed 26600000 <row/> elements
# Processed 26700000 <row/> elements
# Processed 26800000 <row/> elements
# Processed 26900000 <row/> elements
# Processed 27000000 <row/> elements
# Processed 27100000 <row/> elements
# Processed 27200000 <row/> elements
# Processed 27300000 <row/> elements
# Processed 27400000 <row/> elements
# Processed 27500000 <row/> elements
# Processed 27600000 <row/> elements
# Processed 27700000 <row/> elements
# Processed 27800000 <row/> elements
# Processed 27900000 <row/> elements
# Processed 28000000 <row/> elements
# Processed 28100000 <row/> elements
# Processed 28200000 <row/> elements
# Processed 28300000 <row/> elements
# Processed 28400000 <row/> elements
# Processed 28500000 <row/> elements
# Processed 28600000 <row/> elements
# Processed 28700000 <row/> elements
# Processed 28800000 <row/> elements
# Processed 28900000 <row/> elements
# Processed 29000000 <row/> elements
# Processed 29100000 <row/> elements
# Processed 29200000 <row/> elements
# Processed 29300000 <row/> elements
# Processed 29400000 <row/> elements
# Processed 29500000 <row/> elements
# Processed 29600000 <row/> elements
# Processed 29700000 <row/> elements
# Processed 29800000 <row/> elements
# Processed 29900000 <row/> elements
# Processed 30000000 <row/> elements
# Processed 30100000 <row/> elements
# Processed 30200000 <row/> elements
# Processed 30300000 <row/> elements
# Processed 30400000 <row/> elements
# Processed 30500000 <row/> elements
# Processed 30600000 <row/> elements
# Processed 30700000 <row/> elements
# Processed 30800000 <row/> elements
# Processed 30900000 <row/> elements
# Processed 31000000 <row/> elements
# Processed 31100000 <row/> elements
# Processed 31200000 <row/> elements
# Processed 31300000 <row/> elements
# Processed 31400000 <row/> elements
# Processed 31500000 <row/> elements
# Processed 31600000 <row/> elements
# Processed 31700000 <row/> elements
# Processed 31800000 <row/> elements
# Processed 31900000 <row/> elements
# Processed 32000000 <row/> elements
# Processed 32100000 <row/> elements
# Processed 32200000 <row/> elements
# Processed 32300000 <row/> elements
# Processed 32400000 <row/> elements
# Processed 32500000 <row/> elements
# Processed 32600000 <row/> elements
# Processed 32700000 <row/> elements
# Processed 32800000 <row/> elements
# Processed 32900000 <row/> elements
# Processed 33000000 <row/> elements
# Processed 33100000 <row/> elements
# Processed 33200000 <row/> elements
# Processed 33300000 <row/> elements
# Processed 33400000 <row/> elements
# Processed 33500000 <row/> elements
# Processed 33600000 <row/> elements
# Processed 33700000 <row/> elements
# Processed 33800000 <row/> elements
# Processed 33900000 <row/> elements
# Processed 34000000 <row/> elements
# Processed 34100000 <row/> elements
# Processed 34200000 <row/> elements
# Processed 34300000 <row/> elements
# Processed 34400000 <row/> elements
# Processed 34500000 <row/> elements
# Processed 34600000 <row/> elements
# Processed 34700000 <row/> elements
# Processed 34800000 <row/> elements
# Processed 34900000 <row/> elements
# Processed 35000000 <row/> elements
# Processed 35100000 <row/> elements
# Processed 35200000 <row/> elements
# Processed 35300000 <row/> elements
# Processed 35400000 <row/> elements
# Processed 35500000 <row/> elements
# Processed 35600000 <row/> elements
# Processed 35700000 <row/> elements
# Processed 35800000 <row/> elements
# Processed 35900000 <row/> elements
# Processed 36000000 <row/> elements
# Processed 36100000 <row/> elements
# Processed 36200000 <row/> elements
# Processed 36300000 <row/> elements
# Processed 36400000 <row/> elements
# Processed 36500000 <row/> elements
# Processed 36600000 <row/> elements
# Processed 36700000 <row/> elements
# Processed 36800000 <row/> elements
# Processed 36900000 <row/> elements
# Processed 37000000 <row/> elements
# Processed 37100000 <row/> elements
# Processed 37200000 <row/> elements
# Processed 37300000 <row/> elements
# Processed 37400000 <row/> elements
# Processed 37500000 <row/> elements
# Processed 37600000 <row/> elements
# Processed 37700000 <row/> elements
# Processed 37800000 <row/> elements
# Processed 37900000 <row/> elements
# Processed 38000000 <row/> elements
# Processed 38100000 <row/> elements
# Processed 38200000 <row/> elements
# Processed 38300000 <row/> elements
# Processed 38400000 <row/> elements
# Processed 38500000 <row/> elements
# Processed 38600000 <row/> elements
# Processed 38700000 <row/> elements
# Processed 38800000 <row/> elements
# Processed 38900000 <row/> elements
# Processed 39000000 <row/> elements
# Processed 39100000 <row/> elements
# Processed 39200000 <row/> elements
# Processed 39300000 <row/> elements
# Processed 39400000 <row/> elements
# Processed 39500000 <row/> elements
# Processed 39600000 <row/> elements
# Processed 39700000 <row/> elements
# Processed 39800000 <row/> elements
# Processed 39900000 <row/> elements
# Processed 40000000 <row/> elements
# Processed 40100000 <row/> elements
# Processed 40200000 <row/> elements
# Processed 40300000 <row/> elements
# Processed 40400000 <row/> elements
# Processed 40500000 <row/> elements
# Processed 40600000 <row/> elements
# Processed 40700000 <row/> elements
# Processed 40800000 <row/> elements
# Processed 40900000 <row/> elements
# Processed 41000000 <row/> elements
# Processed 41100000 <row/> elements
# Processed 41200000 <row/> elements
# Processed 41300000 <row/> elements
# Processed 41400000 <row/> elements
# Processed 41500000 <row/> elements
# Processed 41600000 <row/> elements
# Processed 41700000 <row/> elements
# Processed 41800000 <row/> elements
# Processed 41900000 <row/> elements
# Processed 42000000 <row/> elements
# Processed 42100000 <row/> elements
# Processed 42200000 <row/> elements
# Processed 42300000 <row/> elements
# Processed 42400000 <row/> elements
# Processed 42500000 <row/> elements
# Processed 42600000 <row/> elements
# Processed 42700000 <row/> elements
# Processed 42800000 <row/> elements
# years: defaultdict(<class 'int'>, {2008: 58228, 2009: 343435, 2010: 693699, 2011: 1199348, 2012: 1643669, 2013: 2057819, 2014: 2161843, 2015: 2216006, 2016: 2221316, 2017: 2164548, 2018: 2086031})
# #qestions: 16845942
# #answers: 25908201

# %% [markdown]
# ### Choosing Instances

# %%
try:
    import enchant
    speller = enchant.Dict("en_US")

except:
    print("""\Enchant is not installed, which is not a problem since spell correction features
will not be used in the chapter. If, however, you want to experiment with them
    (highly encouraged!), you can get the library from http://packages.python.org/pyenchant/.
""")

    class EnchantMock:

        def __init__(self):
            pass

        def check(self, word):
            return True
    speller = EnchantMock()

filtered = os.path.join(DATA_DIR, "filtered.tsv")
filtered_meta = os.path.join(DATA_DIR, "filtered-meta.json")

chosen = os.path.join(DATA_DIR, "chosen.tsv")
chosen_meta = os.path.join(DATA_DIR, "chosen-meta.json")

filtered_meta = json.load(open(filtered_meta, "r"))


def misspelled_fraction(p):
    tokens = p.split()
    if not tokens:
        return 0.0
    return 1 - float(sum(speller.check(t) for t in tokens)) / len(tokens)


def data(filename, col=None):
    for line in open(filename, "r"):
        data = line.strip().split("\t")

        # check format
        Id, ParentId, IsAccepted, TimeToAnswer, Score, Text, NumTextTokens, NumCodeLines, LinkCount, NumImages = data

        if col:
            yield data[col]
        else:
            yield data

posts_to_keep = set()
found_questions = 0

num_qestion_sample = 1000

# keep the best and worst, but only if we have one with positive and one with negative score
# filter_method = "negative_positive"

# if true, only keep the lowest scoring answer per class in addition to the accepted one
# filter_method = "only_one_per_class "

# if not None, specifies the number of unaccepted per question
# filter_method = "sample_per_question"
filter_method = "negative_positive"  # warning: this does not retrieve many!
# filter_method = "only_one_per_class"
MaxAnswersPerQuestions = 10  # filter_method == "sample_per_question"

# filter_method = "all"

# equal share of questions that are unanswered and those that are answered
# filter_method = "half-half"

unaccepted_scores = {}

has_q_accepted_a = {}
num_q_with_accepted_a = 0
num_q_without_accepted_a = 0

for ParentId, posts in filtered_meta.items():
    assert ParentId != -1

    if len(posts) < 2:
        continue

    ParentId = int(ParentId)
    AllIds = set([ParentId])
    AcceptedId = None
    UnacceptedId = None
    UnacceptedIds = []
    UnacceptedScore = sys.maxsize

    NegativeScoreIds = []
    PositiveScoreIds = []

    if filter_method == "half-half":

        has_accepted_a = False
        for post in posts:
            Id, IsAccepted, TimeToAnswer, Score = post

            if IsAccepted:
                has_accepted_a = True
                break

        has_q_accepted_a[ParentId] = has_accepted_a

        if has_accepted_a:
            if num_q_with_accepted_a < num_qestion_sample / 2:
                num_q_with_accepted_a += 1
                posts_to_keep.add(ParentId)
        else:
            if num_q_without_accepted_a < num_qestion_sample / 2:
                num_q_without_accepted_a += 1
                posts_to_keep.add(ParentId)

        if num_q_without_accepted_a + num_q_with_accepted_a > num_qestion_sample:
            assert -1 not in posts_to_keep
            break

    else:

        for post in posts:
            Id, IsAccepted, TimeToAnswer, Score = post

            if filter_method == "all":
                AllIds.add(int(Id))

            elif filter_method == "only_one_per_class":
                if IsAccepted:
                    AcceptedId = Id
                elif Score < UnacceptedScore:
                    UnacceptedScore = Score
                    UnacceptedId = Id

            elif filter_method == "sample_per_question":
                if IsAccepted:
                    AcceptedId = Id
                else:
                    UnacceptedIds.append(Id)

            elif filter_method == "negative_positive":
                if Score < 0:
                    NegativeScoreIds.append((Score, Id))
                elif Score > 0:
                    PositiveScoreIds.append((Score, Id))

            else:
                raise ValueError(filter_method)

        added = False
        if filter_method == "all":
            posts_to_keep.update(AllIds)
            added = True
        elif filter_method == "only_one_per_class":
            if AcceptedId is not None and UnacceptedId is not None:
                posts_to_keep.add(ParentId)
                posts_to_keep.add(AcceptedId)
                posts_to_keep.add(UnacceptedId)
                added = True

        elif filter_method == "sample_per_question":
            if AcceptedId is not None and UnacceptedIds is not None:
                posts_to_keep.add(ParentId)
                posts_to_keep.add(AcceptedId)
                posts_to_keep.update(UnacceptedIds[:MaxAnswersPerQuestions])
                added = True

        elif filter_method == "negative_positive":
            if PositiveScoreIds and NegativeScoreIds:
                posts_to_keep.add(ParentId)

                posScore, posId = sorted(PositiveScoreIds)[-1]
                posts_to_keep.add(posId)

                negScore, negId = sorted(NegativeScoreIds)[0]
                posts_to_keep.add(negId)
                print("%i: %i/%i %i/%i" % (ParentId, posId,
                      posScore, negId, negScore))
                added = True

        if added:
            found_questions += 1

    if num_qestion_sample and found_questions >= num_qestion_sample:
        break

total = 0
kept = 0

already_written = set()
chosen_meta_dict = defaultdict(dict)

with open(chosen, "w") as f:
    for line in data(filtered):
        strId, ParentId, IsAccepted, TimeToAnswer, Score, Text, NumTextTokens, NumCodeLines, LinkCount, NumImages = line
        Text = Text.strip()

        total += 1

        Id = int(strId)
        if Id in posts_to_keep:
            if Id in already_written:
                print(Id, "is already written")
                continue

            if kept % 100 == 0:
                print(kept)

            # setting meta info
            post = chosen_meta_dict[Id]
            post['ParentId'] = int(ParentId)
            post['IsAccepted'] = int(IsAccepted)
            post['TimeToAnswer'] = int(TimeToAnswer)
            post['Score'] = int(Score)
            post['NumTextTokens'] = int(NumTextTokens)
            post['NumCodeLines'] = int(NumCodeLines)
            post['LinkCount'] = int(LinkCount)
            post['MisSpelledFraction'] = misspelled_fraction(Text)
            post['NumImages'] = int(NumImages)
            post['idx'] = kept  # index into the file

            if int(ParentId) == -1:
                q = chosen_meta_dict[Id]

                if not 'Answers' in q:
                    q['Answers'] = []

                if filter_method == "half-half":
                    q['HasAcceptedAnswer'] = has_q_accepted_a[Id]

            else:
                q = chosen_meta_dict[int(ParentId)]

                if int(IsAccepted) == 1:
                    assert 'HasAcceptedAnswer' not in q
                    q['HasAcceptedAnswer'] = True

                if 'Answers' not in q:
                    q['Answers'] = [Id]
                else:
# 70537: 71087/20 46753756/-1
# 70579: 79022/1531 25827288/-4
# 70575: 70634/8 11664488/-1
# 70529: 70657/161 8073228/-1
# 70653: 80008/10 10495626/-1
# 70689: 71399/733 19849576/-5
# 70781: 70810/8 155468/-1
# 70785: 84955/6 70920/-1
# 70947: 70976/152 10434668/-2
# 67685: 779513/4 107523/-2
# 70855: 15501449/368 19789433/-3
# 71022: 6871572/715 31914496/-3
# 71077: 71099/12 71101/-1
# 70992: 71499/14 74284/-4
# 71180: 71310/42 71197/-2
# 71254: 277661/72 71717/-1
# 71328: 71444/58 77689/-1
# 71419: 71471/33 71532/-1
# 71566: 71576/9 71591/-1
# 71625: 74400/285 71699/-6
# 71423: 71665/16 15474300/-1
# 71775: 72018/3 71804/-2
# 71985: 72039/18 75430/-1
# 72014: 72113/2 72941/-1
# 72121: 72145/51 72139/-6
# 72116: 72571/8 72356/-1
# 72125: 73077/5 72887/-1
# 72166: 74513/64 75030/-2
# 72209: 72694/285 47574991/-2
# 72198: 72659/1 72282/-2
# 72264: 72296/16 2614743/-2
# 72271: 72409/199 6773704/-3
# 72275: 17530556/246 19765698/-3
# 72240: 92367/4 72353/-1
# 72381: 72438/17 13409132/-1
# 72358: 83182/10 72413/-1
# 72422: 72504/11 72702/-1
# 72458: 10024434/3 72652/-2
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# total= 42753199
# kept= 3000

# %% [markdown]
# ### PosTagFreqVectorizer

# %%
import scipy.sparse as sp

from sklearn.base import BaseEstimator
from sklearn.feature_extraction.text import strip_accents_ascii, strip_accents_unicode

# %%
poscache_filename = "poscache.json"


class PosCounter(Counter):

    def __init__(self, iterable=(), normalize=True, poscache=None, **kwargs):
        self.n_sents = 0
        self.normalize = normalize

        self.poscache = poscache

        super(PosCounter, self).__init__(iterable, **kwargs)

    def update(self, other):
        """Adds counts for elements in other"""
        if isinstance(other, self.__class__):
            self.n_sents += other.n_sents
            for x, n in other.items():
                self[x] += n
        else:
            for sent in other:
                self.n_sents += 1

                if self.poscache is not None:
                    if sent in self.poscache:
                        tags = self.poscache[sent]
                    else:
                        self.poscache[sent] = tags = nltk.pos_tag(
                            nltk.word_tokenize(sent))
                else:
                    tags = nltk.pos_tag(nltk.word_tokenize(sent))

                for x in tags:
                    tok, tag = x
                    self[tag] += 1

            if self.normalize:
                for x, n in self.items():
                    self[x] /= float(self.n_sents)


class PosTagFreqVectorizer(BaseEstimator):

    """
    Convert a collection of raw documents to a matrix Pos tag frequencies
    """

    def __init__(self, input='content', charset='utf-8',
                 charset_error='strict', strip_accents=None,
                 vocabulary=None,
                 normalize=True,
                 dtype=float):

        self.input = input
        self.charset = charset
        self.charset_error = charset_error
        self.strip_accents = strip_accents
        if vocabulary is not None:
            self.fixed_vocabulary = True
            if not isinstance(vocabulary, Mapping):
                vocabulary = dict((t, i) for i, t in enumerate(vocabulary))
            self.vocabulary_ = vocabulary
        else:
            self.fixed_vocabulary = False

        try:
            self.poscache = json.load(open(poscache_filename, "r"))
        except IOError:
            self.poscache = {}

        self.normalize = normalize
        self.dtype = dtype

    def write_poscache(self):
        json.dump(self.poscache, open(poscache_filename, "w"))

    def decode(self, doc):
        """Decode the input into a string of unicode symbols
        The decoding strategy depends on the vectorizer parameters.
        """
        if self.input == 'filename':
            doc = open(doc, 'rb').read()

        elif self.input == 'file':
            doc = doc.read()

        if isinstance(doc, bytes):
            doc = doc.decode(self.charset, self.charset_error)
        return doc

    def build_preprocessor(self):
        """Return a function to preprocess the text before tokenization"""

        # unfortunately python functools package does not have an efficient
        # `compose` function that would have allowed us to chain a dynamic
        # number of functions. However the however of a lambda call is a few
        # hundreds of nanoseconds which is negligible when compared to the
        # cost of tokenizing a string of 1000 chars for instance.
        noop = lambda x: x

        # accent stripping
        if not self.strip_accents:
            strip_accents = noop
        elif hasattr(self.strip_accents, '__call__'):
            strip_accents = self.strip_accents
        elif self.strip_accents == 'ascii':
            strip_accents = strip_accents_ascii
        elif self.strip_accents == 'unicode':
            strip_accents = strip_accents_unicode
        else:
            raise ValueError('Invalid value for "strip_accents": %s' %
                             self.strip_accents)

        only_prose = lambda s: re.sub('<[^>]*>', '', s).replace("\n", " ")

        return lambda x: strip_accents(only_prose(x))

    def build_tokenizer(self):
        """Return a function that split a string in sequence of tokens"""
        return nltk.sent_tokenize

    def build_analyzer(self):
        """Return a callable that handles preprocessing and tokenization"""

        preprocess = self.build_preprocessor()

        tokenize = self.build_tokenizer()

        return lambda doc: tokenize(preprocess(self.decode(doc)))

    def _term_count_dicts_to_matrix(self, term_count_dicts):
        i_indices = []
        j_indices = []
        values = []
        vocabulary = self.vocabulary_

        for i, term_count_dict in enumerate(term_count_dicts):
            for term, count in term_count_dict.items():
                j = vocabulary.get(term)
                if j is not None:
                    i_indices.append(i)
                    j_indices.append(j)
                    values.append(count)
            # free memory as we go
            term_count_dict.clear()

        shape = (len(term_count_dicts), max(vocabulary.values()) + 1)
        spmatrix = sp.csr_matrix((values, (i_indices, j_indices)),
                                 shape=shape, dtype=self.dtype)
        return spmatrix

    def fit(self, raw_documents, y=None):
        """Learn a vocabulary dictionary of all tokens in the raw documents
        Parameters
        ----------
        raw_documents: iterable
            an iterable which yields either str, unicode or file objects
        Returns
        -------
        self
        """
        self.fit_transform(raw_documents)
        return self

    def fit_transform(self, raw_documents, y=None):
        """Learn the vocabulary dictionary and return the count vectors
        This is more efficient than calling fit followed by transform.
        Parameters
        ----------
        raw_documents: iterable
            an iterable which yields either str, unicode or file objects
        Returns
        -------
        vectors: array, [n_samples, n_features]
        """
        if self.fixed_vocabulary:
            # No need to fit anything, directly perform the transformation.
            # We intentionally don't call the transform method to make it
            # fit_transform overridable without unwanted side effects in
            # TfidfVectorizer
            analyze = self.build_analyzer()
            term_counts_per_doc = [PosCounter(analyze(doc), normalize=self.normalize, poscache=self.poscache)
                                   for doc in raw_documents]
            return self._term_count_dicts_to_matrix(term_counts_per_doc)

        self.vocabulary_ = {}
        # result of document conversion to term count dicts
        term_counts_per_doc = []
        term_counts = Counter()

        analyze = self.build_analyzer()

        for doc in raw_documents:
            term_count_current = PosCounter(
                analyze(doc), normalize=self.normalize, poscache=self.poscache)
            term_counts.update(term_count_current)

            term_counts_per_doc.append(term_count_current)

        self.write_poscache()

        terms = set(term_counts)

        # store map from term name to feature integer index: we sort the term
        # to have reproducible outcome for the vocabulary structure: otherwise
        # the mapping from feature name to indices might depend on the memory
        # layout of the machine. Furthermore sorted terms might make it
        # possible to perform binary search in the feature names array.
        self.vocabulary_ = dict(((t, i) for i, t in enumerate(sorted(terms))))

        return self._term_count_dicts_to_matrix(term_counts_per_doc)

    def transform(self, raw_documents):
        """Extract token counts out of raw text documents using the vocabulary
        fitted with fit or the one provided in the constructor.
        Parameters
        ----------
        raw_documents: iterable
            an iterable which yields either str, unicode or file objects
        Returns
        -------
        vectors: sparse matrix, [n_samples, n_features]
        """
        if not hasattr(self, 'vocabulary_') or len(self.vocabulary_) == 0:
            raise ValueError("Vocabulary wasn't fitted or is empty!")

        # raw_documents can be an iterable so we don't know its size in
        # advance

        # XXX @larsmans tried to parallelize the following loop with joblib.
        # The result was some 20% slower than the serial version.
        analyze = self.build_analyzer()
        term_counts_per_doc = [Counter(analyze(doc)) for doc in raw_documents]
        return self._term_count_dicts_to_matrix(term_counts_per_doc)

    def get_feature_names(self):
        """Array mapping from feature integer indices to feature name"""
        if not hasattr(self, 'vocabulary_') or len(self.vocabulary_) == 0:
            raise ValueError("Vocabulary wasn't fitted or is empty!")

        return [t for t, i in sorted(iter(self.vocabulary_.items()),
                                     key=itemgetter(1))]

# %% [markdown]
# ## Looking into Logistic Regression

# %%
CHART_DIR ="./charts"

np.random.seed(42)

num_per_class = 40
X = np.hstack((norm.rvs(2, size=num_per_class, scale=2),
              norm.rvs(8, size=num_per_class, scale=3)))
y = np.hstack((np.zeros(num_per_class),
               np.ones(num_per_class)))


def lr_model(clf, X):
    return 1.0 / (1.0 + np.exp(-(clf.intercept_ + clf.coef_ * X)))

from sklearn.linear_model import LogisticRegression
logclf = LogisticRegression()
print(logclf)
logclf.fit(X.reshape(num_per_class * 2, 1), y)
print(np.exp(logclf.intercept_), np.exp(logclf.coef_.ravel()))
print("P(x=-1)=%.2f\tP(x=7)=%.2f" %
      (lr_model(logclf, -1), lr_model(logclf, 7)))
X_test = np.arange(-5, 20, 0.1)
pyplot.figure(figsize=(10, 4))
pyplot.xlim((-5, 20))
pyplot.scatter(X, y, c=y)
pyplot.xlabel("feature value")
pyplot.ylabel("class")
pyplot.grid(True, linestyle='-', color='0.75')
pyplot.savefig(
    os.path.join(CHART_DIR, "log_reg_example_data.png"), bbox_inches="tight")


def lin_model(clf, X):
    return clf.intercept_ + clf.coef_ * X

from sklearn.linear_model import LinearRegression
clf = LinearRegression()
print(clf)
clf.fit(X.reshape(num_per_class * 2, 1), y)
X_odds = np.arange(0, 1, 0.001)
pyplot.figure(figsize=(10, 4))
pyplot.subplot(1, 2, 1)
pyplot.scatter(X, y, c=y)
pyplot.plot(X_test, lin_model(clf, X_test))
pyplot.xlabel("feature value")
pyplot.ylabel("class")
pyplot.title("linear fit on original data")
pyplot.grid(True, linestyle='-', color='0.75')

X_ext = np.hstack((X, norm.rvs(20, size=100, scale=5)))
y_ext = np.hstack((y, np.ones(100)))
clf = LinearRegression()
clf.fit(X_ext.reshape(num_per_class * 2 + 100, 1), y_ext)
pyplot.subplot(1, 2, 2)
pyplot.scatter(X_ext, y_ext, c=y_ext)
pyplot.plot(X_ext, lin_model(clf, X_ext))
pyplot.xlabel("feature value")
pyplot.ylabel("class")
pyplot.title("linear fit on additional data")
pyplot.grid(True, linestyle='-', color='0.75')
pyplot.savefig(
    os.path.join(CHART_DIR, "log_reg_log_linear_fit.png"), bbox_inches="tight")

pyplot.figure(figsize=(10, 4))
pyplot.xlim((-5, 20))
pyplot.scatter(X, y, c=y)
pyplot.plot(X_test, lr_model(logclf, X_test).ravel())
pyplot.plot(X_test, np.ones(X_test.shape[0]) * 0.5, "--")
pyplot.xlabel("feature value")
pyplot.ylabel("class")
pyplot.grid(True, linestyle='-', color='0.75')
pyplot.savefig(
    os.path.join(CHART_DIR, "log_reg_example_fitted.png"), bbox_inches="tight")

X = np.arange(0, 1, 0.001)
pyplot.figure(figsize=(10, 4))
pyplot.subplot(1, 2, 1)
pyplot.xlim((0, 1))
pyplot.ylim((0, 10))
pyplot.plot(X, X / (1 - X))
pyplot.xlabel("P")
pyplot.ylabel("odds = P / (1-P)")
pyplot.grid(True, linestyle='-', color='0.75')

pyplot.subplot(1, 2, 2)
pyplot.xlim((0, 1))
pyplot.plot(X, np.log(X / (1 - X)))
pyplot.xlabel("P")
pyplot.ylabel("log(odds) = log(P / (1-P))")
pyplot.grid(True, linestyle='-', color='0.75')
pyplot.savefig(
    os.path.join(CHART_DIR, "log_reg_log_odds.png"), bbox_inches="tight")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# [0.09437188] [1.80094112]
# P(x=-1)=0.05	P(x=7)=0.85
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:92: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ## Helper Functions

# %%
CHART_DIR ="./charts"

def fetch_data(filename, col=None, line_count=-1, only_questions=False):
    count = 0

    for line in open(filename, "r"):
        count += 1
        if line_count > 0 and count > line_count:
            break

        data = Id, ParentId, IsQuestion, IsAccepted, TimeToAnswer, Score, Text, NumTextTokens, NumCodeLines, LinkCount, MisSpelledFraction = line.split(
            "\t")

        IsQuestion = int(IsQuestion)

        if only_questions and not IsQuestion:
            continue

        if col:
            if col < 6:
                val = int(data[col])
            else:
                val = data[col]

            yield val

        else:
            Id = int(Id)
            assert Id >= 0, line

            ParentId = int(ParentId)

            IsAccepted = int(IsAccepted)

            assert not IsQuestion == IsAccepted == 1, "%i %i --- %s" % (
                IsQuestion, IsAccepted, line)
            assert (ParentId == -1 and IsQuestion) or (
                ParentId >= 0 and not IsQuestion), "%i %i --- %s" % (ParentId, IsQuestion, line)

            TimeToAnswer = int(TimeToAnswer)
            Score = int(Score)
            NumTextTokens = int(NumTextTokens)
            NumCodeLines = int(NumCodeLines)
            LinkCount = int(LinkCount)
            MisSpelledFraction = float(MisSpelledFraction)
            yield Id, ParentId, IsQuestion, IsAccepted, TimeToAnswer, Score, Text, NumTextTokens, NumCodeLines, LinkCount, MisSpelledFraction


def fetch_posts(filename, with_index=True, line_count=-1):
    count = 0

    for line in open(filename, "r"):
        count += 1
        if line_count > 0 and count > line_count:
            break

        Id, Text = line.split("\t")
        Text = Text.strip()

        if with_index:

            yield int(Id), Text

        else:

            yield Text


def load_meta(filename):
    meta = json.load(open(filename, "r"))
    keys = list(meta.keys())

    # JSON only allows string keys, changing that to int
    for key in keys:
        meta[int(key)] = meta[key]
        del meta[key]

    # post Id to index in vectorized
    id_to_idx = {}
    # and back
    idx_to_id = {}

    for PostId, Info in meta.items():
        id_to_idx[PostId] = idx = Info['idx']
        idx_to_id[idx] = PostId

    return meta, id_to_idx, idx_to_id


def plot_roc(auc_score, name, fpr, tpr):
    pylab.figure(num=None, figsize=(6, 5))
    pylab.plot([0, 1], [0, 1], 'k--')
    pylab.xlim([0.0, 1.0])
    pylab.ylim([0.0, 1.0])
    pylab.xlabel('False Positive Rate')
    pylab.ylabel('True Positive Rate')
    pylab.title('Receiver operating characteristic (AUC=%0.2f)\n%s' % (
        auc_score, name))
    pylab.legend(loc="lower right")
    pylab.grid(True, linestyle='-', color='0.75')
    pylab.fill_between(tpr, fpr, alpha=0.5)
    pylab.plot(fpr, tpr, lw=1)
    pylab.savefig(
        os.path.join(CHART_DIR, "roc_" + name.replace(" ", "_") + ".png"))


def plot_pr(auc_score, name, precision, recall, label=None):
    pylab.figure(num=None, figsize=(6, 5))
    pylab.xlim([0.0, 1.0])
    pylab.ylim([0.0, 1.0])
    pylab.xlabel('Recall')
    pylab.ylabel('Precision')
    pylab.title('P/R (AUC=%0.2f) / %s' % (auc_score, label))
    pylab.fill_between(recall, precision, alpha=0.5)
    pylab.grid(True, linestyle='-', color='0.75')
    pylab.plot(recall, precision, lw=1)
    filename = name.replace(" ", "_")
    pylab.savefig(os.path.join(CHART_DIR, "pr_" + filename + ".png"))


def show_most_informative_features(vectorizer, clf, n=20):
    c_f = sorted(zip(clf.coef_[0], vectorizer.get_feature_names()))
    top = list(zip(c_f[:n], c_f[:-(n + 1):-1]))
    for (c1, f1), (c2, f2) in top:
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (c1, f1, c2, f2))


def plot_feat_importance(feature_names, clf, name):
    pylab.figure(num=None, figsize=(6, 5))
    coef_ = clf.coef_
    important = np.argsort(np.absolute(coef_.ravel()))
    f_imp = feature_names[important]
    coef = coef_.ravel()[important]
    inds = np.argsort(coef)
    f_imp = f_imp[inds]
    coef = coef[inds]
    xpos = np.array(list(range(len(coef))))
    pylab.bar(xpos, coef, width=1)

    pylab.title('Feature importance for %s' % (name))
    ax = pylab.gca()
    ax.set_xticks(np.arange(len(coef)))
    labels = ax.set_xticklabels(f_imp)
    for label in labels:
        label.set_rotation(90)
    filename = name.replace(" ", "_")
    pylab.savefig(os.path.join(
        CHART_DIR, "feat_imp_%s.png" % filename), bbox_inches="tight")


def plot_feat_hist(data_name_list, filename=None):
    if len(data_name_list) > 1:
        assert filename is not None

    pylab.figure(num=None, figsize=(8, 6))
    num_rows = int(1 + (len(data_name_list) - 1) / 2)
    num_cols = int(1 if len(data_name_list) == 1 else 2)
    pylab.figure(figsize=(5 * num_cols, 4 * num_rows))

    for i in range(num_rows):
        for j in range(num_cols):
            pylab.subplot(num_rows, num_cols, 1 + i * num_cols + j)
            x, name = data_name_list[i * num_cols + j]
            pylab.title(name)
            pylab.xlabel('Value')
            pylab.ylabel('Fraction')
            # the histogram of the data
            max_val = np.max(x)
            if max_val <= 1.0:
                bins = 50
            elif max_val > 50:
                bins = 50
            else:
                bins = max_val
            n, bins, patches = pylab.hist(x, bins=int(bins), normed=1, alpha=0.75)

            pylab.grid(True)

    if not filename:
        filename = "feat_hist_%s.png" % name.replace(" ", "_")

    pylab.savefig(os.path.join(CHART_DIR, filename), bbox_inches="tight")


def plot_bias_variance(data_sizes, train_errors, test_errors, name, title):
    pylab.figure(num=None, figsize=(6, 5))
    pylab.ylim([0.0, 1.0])
    pylab.xlabel('Data set size')
    pylab.ylabel('Error')
    pylab.title("Bias-Variance for '%s'" % name)
    pylab.plot(
        data_sizes, test_errors, "--", data_sizes, train_errors, "b-", lw=1)
    pylab.legend(["test error", "train error"], loc="upper right")
    pylab.grid(True, linestyle='-', color='0.75')
    pylab.savefig(
        os.path.join(CHART_DIR, "bv_" + name.replace(" ", "_") + ".png"), bbox_inches="tight")


def plot_k_complexity(ks, train_errors, test_errors):
    pylab.figure(num=None, figsize=(6, 5))
    pylab.ylim([0.0, 1.0])
    pylab.xlabel('k')
    pylab.ylabel('Error')
    pylab.title('Errors for for different values of $k$')
    pylab.plot(
        ks, test_errors, "--", ks, train_errors, "-", lw=1)
    pylab.legend(["test error", "train error"], loc="upper right")
    pylab.grid(True, linestyle='-', color='0.75')
    pylab.savefig(
        os.path.join(CHART_DIR, "kcomplexity.png"), bbox_inches="tight")

# %% [markdown]
# ## Classification

# %%
import time

from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.model_selection import KFold
from sklearn import neighbors

import nltk
nltk.download('punkt')
# run this
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Predator\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
start_time = time.time()

# question Id -> {'features'->feature vector, 'answers'->[answer Ids]}, 'scores'->[scores]}
# scores will be added on-the-fly as the are not in meta
meta, id_to_idx, idx_to_id = load_meta(chosen_meta)

# The sorting below is only to ensure reproducable numbers. Further down
# we will occasionally skip a fold when it contains instances of only
# one label. The two lines below ensure that the behavior is exactly the
# same for different runs.
all_questions = sorted([q for q, v in meta.items() if v['ParentId'] == -1])
all_answers = sorted([q for q, v in meta.items() if v['ParentId'] != -1])

feature_names = np.array((
    'NumTextTokens',
    'NumCodeLines',
    'LinkCount',
    'AvgSentLen',
    'AvgWordLen',
    'NumAllCaps',
    'NumExclams',
    'NumImages'
))


def prepare_sent_features():
    for pid, text in fetch_posts(chosen, with_index=True):
        if not text:
            meta[pid]['AvgSentLen'] = meta[pid]['AvgWordLen'] = 0
        else:
            from platform import python_version
            if python_version().startswith('2'):
                text = text.decode('utf-8')
            sent_lens = [len(nltk.word_tokenize(
                sent)) for sent in nltk.sent_tokenize(text)]
            meta[pid]['AvgSentLen'] = np.mean(sent_lens)
            meta[pid]['AvgWordLen'] = np.mean(
                [len(w) for w in nltk.word_tokenize(text)])

        meta[pid]['NumAllCaps'] = np.sum(
            [word.isupper() for word in nltk.word_tokenize(text)])

        meta[pid]['NumExclams'] = text.count('!')


prepare_sent_features()


def get_features(aid):
    return tuple(meta[aid][fn] for fn in feature_names)

qa_X = np.asarray([get_features(aid) for aid in all_answers])

classifying_answer = "good"
#classifying_answer = "poor"

if classifying_answer == "good":
    # Score > 0 tests => positive class is good answer
    qa_Y = np.asarray([meta[aid]['Score'] > 0 for aid in all_answers])
elif classifying_answer == "poor":
    # Score <= 0 tests => positive class is poor answer
    qa_Y = np.asarray([meta[aid]['Score'] <= 0 for aid in all_answers])
else:
    raise Exception("classifying_answer='%s' is not supported" %
                    classifying_answer)

# %%
for idx, feat in enumerate(feature_names):
#     print (idx,feat)
#     print([(qa_X[:, idx], feat)])
    plot_feat_hist([(qa_X[:, idx], feat)])

plot_feat_hist([(qa_X[:, idx], feature_names[idx]) for idx in [1,0]], 'feat_hist_two.png')
plot_feat_hist([(qa_X[:, idx], feature_names[idx]) for idx in [3,4,5,6]], 'feat_hist_four.png')

avg_scores_summary = []

# %%
def measure(clf_class, parameters, name, data_size=None, plot=False):
    start_time_clf = time.time()
    if data_size is None:
        X = qa_X
        Y = qa_Y
    else:
        X = qa_X[:data_size]
        Y = qa_Y[:data_size]

    cv = KFold(n=len(X), n_folds=10)

    train_errors = []
    test_errors = []

    scores = []
    roc_scores = []
    fprs, tprs = [], []

    pr_scores = []
    precisions, recalls, thresholds = [], [], []

    for fold_idx, (train, test) in enumerate(cv):
        X_train, y_train = X[train], Y[train]
        X_test, y_test = X[test], Y[test]

        only_one_class_in_train = len(set(y_train)) == 1
        only_one_class_in_test = len(set(y_test)) == 1
        if only_one_class_in_train or only_one_class_in_test:
            # this would pose problems later on
            continue

        clf = clf_class(**parameters)

        clf.fit(X_train, y_train)

        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)

        train_errors.append(1 - train_score)
        test_errors.append(1 - test_score)

        scores.append(test_score)
        proba = clf.predict_proba(X_test)

        label_idx = 1
        fpr, tpr, roc_thresholds = roc_curve(y_test, proba[:, label_idx])
        precision, recall, pr_thresholds = precision_recall_curve(
            y_test, proba[:, label_idx])

        roc_scores.append(auc(fpr, tpr))
        fprs.append(fpr)
        tprs.append(tpr)

        pr_scores.append(auc(recall, precision))
        precisions.append(precision)
        recalls.append(recall)
        thresholds.append(pr_thresholds)

        # This threshold is determined at the end of the chapter 5,
        # where we find conditions such that precision is in the area of
        # about 80%. With it we trade off recall for precision.
        threshold_for_detecting_good_answers = 0.59

        print("Clone #%i" % fold_idx)
        print(classification_report(y_test, proba[:, label_idx] >
              threshold_for_detecting_good_answers, target_names=['not accepted', 'accepted']))

    # get medium clone
    scores_to_sort = pr_scores  # roc_scores
    medium = np.argsort(scores_to_sort)[int(len(scores_to_sort) / 2)]
    print("Medium clone is #%i" % medium)

    if plot:
        #plot_roc(roc_scores[medium], name, fprs[medium], tprs[medium])
        plot_pr(pr_scores[medium], name, precisions[medium],
                recalls[medium], classifying_answer + " answers")

        if hasattr(clf, 'coef_'):
            plot_feat_importance(feature_names, clf, name)

    summary = (name,
               np.mean(scores), np.std(scores),
               np.mean(roc_scores), np.std(roc_scores),
               np.mean(pr_scores), np.std(pr_scores),
               time.time() - start_time_clf)
    print(summary)
    avg_scores_summary.append(summary)
    precisions = precisions[medium]
    recalls = recalls[medium]
    thresholds = np.hstack(([0], thresholds[medium]))
    idx80 = precisions >= 0.8
    print("P=%.2f R=%.2f thresh=%.2f" % (precisions[idx80][0], recalls[
          idx80][0], thresholds[idx80][0]))

    return np.mean(train_errors), np.mean(test_errors)

# %%
def bias_variance_analysis(clf_class, parameters, name):
    #import ipdb;ipdb.set_trace()
    data_sizes = np.arange(60, 2000, 4)

    train_errors = []
    test_errors = []

    for data_size in data_sizes:
        train_error, test_error = measure(clf_class, parameters, name, data_size=data_size)
        train_errors.append(train_error)
        test_errors.append(test_error)

    plot_bias_variance(data_sizes, train_errors,
                       test_errors, name, "Bias-Variance for '%s'" % name)

# %%
def k_complexity_analysis(clf_class, parameters):
    ks = np.hstack((np.arange(1, 20), np.arange(21, 100, 5)))

    train_errors = []
    test_errors = []

    for k in ks:
        parameters['n_neighbors'] = k
        train_error, test_error = measure(
            clf_class, parameters, "%dNN" % k, data_size=2000)
        train_errors.append(train_error)
        test_errors.append(test_error)

    plot_k_complexity(ks, train_errors, test_errors)

# %%
for k in [5]:
# for k in [5, 10, 40]:
    #measure(neighbors.KNeighborsClassifier, {'n_neighbors': k}, "%iNN" % k)
    bias_variance_analysis(neighbors.KNeighborsClassifier, {'n_neighbors': k}, "%iNN" % k)
    k_complexity_analysis(neighbors.KNeighborsClassifier, {'n_neighbors': k})
# Out:
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.56      0.50      0.51         6
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.60      0.75      0.67         4
#
#  avg / total       0.40      0.50      0.44         6
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         1
#     accepted       1.00      0.60      0.75         5
#
#  avg / total       0.89      0.67      0.71         6
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.40      0.67      0.50         3
#
#  avg / total       0.20      0.33      0.25         6
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.69      0.83      0.76         6
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      1.00      0.67         1
#     accepted       1.00      0.80      0.89         5
#
#  avg / total       0.92      0.83      0.85         6
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.50      0.67      0.57         3
#
#  avg / total       0.50      0.50      0.49         6
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.69      0.83      0.76         6
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.50      1.00      0.67         3
#
#  avg / total       0.25      0.50      0.33         6
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.67      0.67      0.67         6
#
# Medium clone is #8
# ('5NN', 0.6166666666666667, 0.16749792701868152, 0.6425000000000001, 0.23905049443347506, 0.8451111111111113, 0.1210039791203701, 0.03487849235534668)
# P=1.00 R=0.00 thresh=1.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.33      0.33         3
#     accepted       0.50      0.50      0.50         4
#
#  avg / total       0.43      0.43      0.43         7
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.20      1.00      0.33         1
#     accepted       1.00      0.33      0.50         6
#
#  avg / total       0.89      0.43      0.48         7
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.88      0.86      0.84         7
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.80      1.00      0.89         4
#
#  avg / total       0.87      0.83      0.81         6
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.56      0.50      0.51         6
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.69      0.83      0.76         6
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.67      1.00      0.80         4
#
#  avg / total       0.44      0.67      0.53         6
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.50      1.00      0.67         3
#
#  avg / total       0.25      0.50      0.33         6
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.75      0.75      0.75         4
#
#  avg / total       0.67      0.67      0.67         6
#
# Medium clone is #5
# ('5NN', 0.6428571428571429, 0.1604274335992668, 0.62, 0.1338505592899119, 0.807938492063492, 0.10680543224326396, 0.03191375732421875)
# P=1.00 R=0.50 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.33      0.33         3
#     accepted       0.50      0.50      0.50         4
#
#  avg / total       0.43      0.43      0.43         7
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.20      1.00      0.33         1
#     accepted       1.00      0.33      0.50         6
#
#  avg / total       0.89      0.43      0.48         7
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.88      0.86      0.84         7
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.88      0.86      0.84         7
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.60      0.75      0.67         4
#
#  avg / total       0.56      0.57      0.55         7
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.73      0.86      0.79         7
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.57      1.00      0.73         4
#
#  avg / total       0.33      0.57      0.42         7
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.67      1.00      0.80         4
#
#  avg / total       0.44      0.67      0.53         6
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.56      0.50      0.51         6
#
# Medium clone is #5
# ('5NN', 0.6452380952380952, 0.1630387458644761, 0.60875, 0.13769493757336662, 0.7774861111111112, 0.13695195990253342, 0.036902427673339844)
# P=1.00 R=0.00 thresh=0.80
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.33      0.33         3
#     accepted       0.60      0.60      0.60         5
#
#  avg / total       0.50      0.50      0.50         8
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.20      1.00      0.33         1
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.90      0.50      0.57         8
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.75      0.75      0.75         4
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.51      0.71      0.60         7
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         5
#
#  avg / total       1.00      1.00      1.00         7
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.51      0.71      0.60         7
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.57      1.00      0.73         4
#
#  avg / total       0.33      0.57      0.42         7
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Medium clone is #9
# ('5NN', 0.6857142857142857, 0.1362770287738494, 0.6617857142857143, 0.1395860112444918, 0.8333945578231292, 0.09516141963252679, 0.03792572021484375)
# P=0.83 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.75      0.60      0.67         5
#
#  avg / total       0.66      0.62      0.63         8
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.20      1.00      0.33         1
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.90      0.50      0.57         8
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.25      0.33         4
#     accepted       0.50      0.75      0.60         4
#
#  avg / total       0.50      0.50      0.47         8
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.89      0.88      0.86         8
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.50      0.29         2
#     accepted       0.67      0.33      0.44         6
#
#  avg / total       0.55      0.38      0.40         8
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.57      1.00      0.73         4
#
#  avg / total       0.33      0.57      0.42         7
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.60      0.60      0.60         5
#
#  avg / total       0.43      0.43      0.43         7
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.75      0.60      0.67         5
#
#  avg / total       0.63      0.57      0.59         7
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         5
#
#  avg / total       1.00      1.00      1.00         7
#
# Medium clone is #0
# ('5NN', 0.6196428571428572, 0.18882187103085235, 0.6469940476190476, 0.16276679052145537, 0.8371207482993196, 0.10037312125018055, 0.03487873077392578)
# P=1.00 R=0.20 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.75      0.60      0.67         5
#
#  avg / total       0.66      0.62      0.63         8
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.20      1.00      0.33         1
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.90      0.50      0.57         8
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.50      0.57         4
#     accepted       0.60      0.75      0.67         4
#
#  avg / total       0.63      0.62      0.62         8
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         2
#     accepted       1.00      0.33      0.50         6
#
#  avg / total       0.83      0.50      0.50         8
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.62      1.00      0.77         5
#
#  avg / total       0.39      0.62      0.48         8
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.67      0.80      0.73         5
#
#  avg / total       0.60      0.62      0.60         8
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.89      0.88      0.86         8
#
# Medium clone is #8
# ('5NN', 0.6625, 0.1125, 0.7057440476190476, 0.11312578299925712, 0.8617120181405895, 0.09271833953686971, 0.035904884338378906)
# P=0.86 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.75      0.50      0.60         6
#
#  avg / total       0.63      0.56      0.57         9
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.84      0.44      0.44         9
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.64      0.67      0.65         9
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.54      0.62      0.58         8
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.67      0.80      0.73         5
#
#  avg / total       0.60      0.62      0.60         8
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.33      0.33         3
#     accepted       0.60      0.60      0.60         5
#
#  avg / total       0.50      0.50      0.50         8
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         6
#
#  avg / total       1.00      1.00      1.00         8
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Medium clone is #5
# ('5NN', 0.6694444444444445, 0.1517388920416407, 0.7398412698412697, 0.12959848454271058, 0.8739024943310657, 0.09480714265369283, 0.03889584541320801)
# P=1.00 R=0.67 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.75      0.50      0.60         6
#
#  avg / total       0.63      0.56      0.57         9
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.84      0.44      0.44         9
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.64      0.67      0.65         9
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         4
#     accepted       0.50      0.80      0.62         5
#
#  avg / total       0.28      0.44      0.34         9
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.33      0.33         3
#     accepted       0.67      0.67      0.67         6
#
#  avg / total       0.56      0.56      0.56         9
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.72      0.67      0.69         9
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         6
#
#  avg / total       1.00      1.00      1.00         8
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.82      0.75      0.71         8
#
# Medium clone is #4
# ('5NN', 0.663888888888889, 0.16313385400028915, 0.7231746031746031, 0.1009589944923633, 0.8763112244897959, 0.05969919798555561, 0.03490614891052246)
# P=0.83 R=0.83 thresh=0.40
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.33      0.25         3
#     accepted       0.60      0.43      0.50         7
#
#  avg / total       0.48      0.40      0.42        10
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.80      0.57      0.67         7
#
#  avg / total       0.68      0.60      0.62        10
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.64      0.67      0.65         9
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         2
#     accepted       1.00      0.57      0.73         7
#
#  avg / total       0.87      0.67      0.69         9
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         4
#     accepted       0.56      1.00      0.71         5
#
#  avg / total       0.31      0.56      0.40         9
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.64      0.67      0.65         9
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         7
#
#  avg / total       1.00      1.00      1.00         9
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.20      0.33         5
#     accepted       0.50      1.00      0.67         4
#
#  avg / total       0.78      0.56      0.48         9
#
# Medium clone is #1
# ('5NN', 0.6666666666666666, 0.15363898682172092, 0.7211507936507936, 0.15274510576231615, 0.867002551020408, 0.09672163135160929, 0.028922557830810547)
# P=0.83 R=0.71 thresh=0.20
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.33      0.25         3
#     accepted       0.60      0.43      0.50         7
#
#  avg / total       0.48      0.40      0.42        10
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.67      0.44         3
#     accepted       0.75      0.43      0.55         7
#
#  avg / total       0.62      0.50      0.52        10
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.33      0.29         3
#     accepted       0.67      0.57      0.62         7
#
#  avg / total       0.54      0.50      0.52        10
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.60      1.00      0.75         3
#     accepted       1.00      0.71      0.83         7
#
#  avg / total       0.88      0.80      0.81        10
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      0.75      0.75         8
#
#  avg / total       0.60      0.60      0.60        10
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         4
#     accepted       0.67      0.67      0.67         6
#
#  avg / total       0.60      0.60      0.60        10
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.80      0.67      0.73         6
#
#  avg / total       0.70      0.67      0.68         9
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         3
#     accepted       1.00      1.00      1.00         6
#
#  avg / total       1.00      1.00      1.00         9
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         6
#     accepted       0.33      1.00      0.50         3
#
#  avg / total       0.11      0.33      0.17         9
#
# Medium clone is #1
# ('5NN', 0.6177777777777778, 0.19078784028338913, 0.6729166666666667, 0.16313460812617514, 0.822721797052154, 0.14029166954588, 0.02892303466796875)
# P=0.80 R=0.57 thresh=0.20
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.33      0.25         3
#     accepted       0.60      0.43      0.50         7
#
#  avg / total       0.48      0.40      0.42        10
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.67      0.44         3
#     accepted       0.75      0.43      0.55         7
#
#  avg / total       0.62      0.50      0.52        10
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.33      0.29         3
#     accepted       0.67      0.57      0.62         7
#
#  avg / total       0.54      0.50      0.52        10
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.60      1.00      0.75         3
#     accepted       1.00      0.71      0.83         7
#
#  avg / total       0.88      0.80      0.81        10
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      0.75      0.75         8
#
#  avg / total       0.60      0.60      0.60        10
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.25      0.29         4
#     accepted       0.57      0.67      0.62         6
#
#  avg / total       0.48      0.50      0.48        10
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.73      0.70      0.71        10
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         3
#     accepted       1.00      1.00      1.00         7
#
#  avg / total       1.00      1.00      1.00        10
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.25      0.33         4
#     accepted       0.62      0.83      0.71         6
#
#  avg / total       0.57      0.60      0.56        10
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.14      0.22         7
#     accepted       0.25      0.67      0.36         3
#
#  avg / total       0.42      0.30      0.26        10
#
# Medium clone is #5
# ('5NN', 0.59, 0.19209372712298547, 0.6427083333333333, 0.16099849484250867, 0.7991007653061224, 0.14883763118804202, 0.03191494941711426)
# P=1.00 R=0.50 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.17      0.33      0.22         3
#     accepted       0.60      0.38      0.46         8
#
#  avg / total       0.48      0.36      0.40        11
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.50      0.44         4
#     accepted       0.67      0.57      0.62         7
#
#  avg / total       0.57      0.55      0.55        11
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.33      0.29         3
#     accepted       0.71      0.62      0.67         8
#
#  avg / total       0.59      0.55      0.56        11
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.82      0.82      0.82        11
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.25      0.29         4
#     accepted       0.57      0.67      0.62         6
#
#  avg / total       0.48      0.50      0.48        10
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.80      0.57      0.67         7
#
#  avg / total       0.68      0.60      0.62        10
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.80      0.80      0.80        10
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.80      0.80      0.80        10
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.17      0.25         6
#     accepted       0.38      0.75      0.50         4
#
#  avg / total       0.45      0.40      0.35        10
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.40      0.50         5
#     accepted       0.57      0.80      0.67         5
#
#  avg / total       0.62      0.60      0.58        10
#
# Medium clone is #3
# ('5NN', 0.5972727272727273, 0.15470847017471817, 0.6613333333333334, 0.12940089362072146, 0.7791585433415791, 0.19068657274443596, 0.03490614891052246)
# P=0.88 R=0.88 thresh=0.40
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.17      0.33      0.22         3
#     accepted       0.60      0.38      0.46         8
#
#  avg / total       0.48      0.36      0.40        11
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.50      0.44         4
#     accepted       0.67      0.57      0.62         7
#
#  avg / total       0.57      0.55      0.55        11
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.83      0.62      0.71         8
#
#  avg / total       0.72      0.64      0.66        11
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.82      0.82      0.82        11
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.25      0.29         4
#     accepted       0.62      0.71      0.67         7
#
#  avg / total       0.52      0.55      0.53        11
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.67      0.44         3
#     accepted       0.80      0.50      0.62         8
#
#  avg / total       0.67      0.55      0.57        11
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.75      0.86         4
#     accepted       0.88      1.00      0.93         7
#
#  avg / total       0.92      0.91      0.91        11
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.33      0.33         3
#     accepted       0.75      0.75      0.75         8
#
#  avg / total       0.64      0.64      0.64        11
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         6
#     accepted       0.40      1.00      0.57         4
#
#  avg / total       0.16      0.40      0.23        10
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.40      0.57         5
#     accepted       0.62      1.00      0.77         5
#
#  avg / total       0.81      0.70      0.67        10
#
# Medium clone is #7
# ('5NN', 0.6100000000000001, 0.16111440419673662, 0.6417380952380951, 0.13193061247465088, 0.769059568903319, 0.15123055685161532, 0.031914472579956055)
# P=0.80 R=0.50 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.29      0.50      0.36         4
#     accepted       0.60      0.38      0.46         8
#
#  avg / total       0.50      0.42      0.43        12
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.43      0.75      0.55         4
#     accepted       0.80      0.50      0.62         8
#
#  avg / total       0.68      0.58      0.59        12
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.88      0.78      0.82         9
#
#  avg / total       0.78      0.73      0.75        11
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.86      0.75      0.80         8
#
#  avg / total       0.76      0.73      0.74        11
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.25      0.33         4
#     accepted       0.67      0.86      0.75         7
#
#  avg / total       0.61      0.64      0.60        11
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         4
#     accepted       0.71      0.71      0.71         7
#
#  avg / total       0.64      0.64      0.64        11
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.75      1.00      0.86         3
#     accepted       1.00      0.88      0.93         8
#
#  avg / total       0.93      0.91      0.91        11
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.25      0.25         4
#     accepted       0.57      0.57      0.57         7
#
#  avg / total       0.45      0.45      0.45        11
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.29      0.44         7
#     accepted       0.44      1.00      0.62         4
#
#  avg / total       0.80      0.55      0.51        11
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         6
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.87      0.82      0.82        11
#
# Medium clone is #3
# ('5NN', 0.6454545454545455, 0.14681341268796674, 0.6744742063492064, 0.1545957708719878, 0.7666591295609153, 0.16792694790906074, 0.03091740608215332)
# P=0.86 R=0.75 thresh=0.40
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.29      0.50      0.36         4
#     accepted       0.60      0.38      0.46         8
#
#  avg / total       0.50      0.42      0.43        12
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.43      0.75      0.55         4
#     accepted       0.80      0.50      0.62         8
#
#  avg / total       0.68      0.58      0.59        12
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         2
#     accepted       0.88      0.70      0.78        10
#
#  avg / total       0.77      0.67      0.70        12
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.83      0.62      0.71         8
#
#  avg / total       0.72      0.67      0.68        12
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.50      0.57         4
#     accepted       0.78      0.88      0.82         8
#
#  avg / total       0.74      0.75      0.74        12
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.75      0.67         4
#     accepted       0.86      0.75      0.80         8
#
#  avg / total       0.77      0.75      0.76        12
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         2
#     accepted       1.00      0.67      0.80         9
#
#  avg / total       0.89      0.73      0.76        11
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.43      0.50         7
#     accepted       0.33      0.50      0.40         4
#
#  avg / total       0.50      0.45      0.46        11
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.50      0.60         6
#     accepted       0.57      0.80      0.67         5
#
#  avg / total       0.67      0.64      0.63        11
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         6
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.87      0.82      0.82        11
#
# Medium clone is #5
# ('5NN', 0.646969696969697, 0.12328716282689912, 0.6590922619047619, 0.13256524102565037, 0.7140895562770563, 0.21668305407932298, 0.028922557830810547)
# P=0.86 R=0.75 thresh=0.40
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.29      0.50      0.36         4
#     accepted       0.60      0.38      0.46         8
#
#  avg / total       0.50      0.42      0.43        12
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         4
#     accepted       0.67      0.50      0.57         8
#
#  avg / total       0.56      0.50      0.51        12
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         2
#     accepted       0.88      0.70      0.78        10
#
#  avg / total       0.77      0.67      0.70        12
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.83      0.62      0.71         8
#
#  avg / total       0.72      0.67      0.68        12
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.83      0.83      0.83        12
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.75      0.67         4
#     accepted       0.86      0.75      0.80         8
#
#  avg / total       0.77      0.75      0.76        12
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      1.00      0.67         3
#     accepted       1.00      0.67      0.80         9
#
#  avg / total       0.88      0.75      0.77        12
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.14      0.20         7
#     accepted       0.33      0.60      0.43         5
#
#  avg / total       0.33      0.33      0.30        12
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         6
#     accepted       0.60      1.00      0.75         6
#
#  avg / total       0.80      0.67      0.62        12
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.83      0.71      0.77         7
#     accepted       0.67      0.80      0.73         5
#
#  avg / total       0.76      0.75      0.75        12
#
# Medium clone is #9
# ('5NN', 0.6333333333333334, 0.15456030825826172, 0.6748511904761905, 0.14976140498345708, 0.759387536075036, 0.16903453741199434, 0.030917644500732422)
# P=1.00 R=0.40 thresh=0.80
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         4
#     accepted       0.60      0.33      0.43         9
#
#  avg / total       0.49      0.38      0.40        13
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         4
#     accepted       0.71      0.56      0.63         9
#
#  avg / total       0.60      0.54      0.56        13
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.86      0.67      0.75         9
#
#  avg / total       0.75      0.69      0.70        13
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.73      0.80      0.76        10
#
#  avg / total       0.56      0.62      0.59        13
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.71      1.00      0.83         5
#     accepted       1.00      0.71      0.83         7
#
#  avg / total       0.88      0.83      0.83        12
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.88      0.78      0.82         9
#
#  avg / total       0.78      0.75      0.76        12
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.50      0.44         4
#     accepted       0.71      0.62      0.67         8
#
#  avg / total       0.61      0.58      0.59        12
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.25      0.36         8
#     accepted       0.33      0.75      0.46         4
#
#  avg / total       0.56      0.42      0.40        12
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         6
#     accepted       0.67      1.00      0.80         6
#
#  avg / total       0.83      0.75      0.73        12
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.33      0.44         6
#     accepted       0.56      0.83      0.67         6
#
#  avg / total       0.61      0.58      0.56        12
#
# Medium clone is #5
# ('5NN', 0.6147435897435897, 0.137975464474102, 0.6734540343915343, 0.1317897981262853, 0.7764770414770414, 0.1518070370188255, 0.03193402290344238)
# P=0.82 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         4
#     accepted       0.60      0.33      0.43         9
#
#  avg / total       0.49      0.38      0.40        13
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         4
#     accepted       0.71      0.56      0.63         9
#
#  avg / total       0.60      0.54      0.56        13
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.86      0.67      0.75         9
#
#  avg / total       0.75      0.69      0.70        13
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.73      0.80      0.76        10
#
#  avg / total       0.56      0.62      0.59        13
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.71      1.00      0.83         5
#     accepted       1.00      0.75      0.86         8
#
#  avg / total       0.89      0.85      0.85        13
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.75      0.67         4
#     accepted       0.88      0.78      0.82         9
#
#  avg / total       0.79      0.77      0.78        13
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.25      0.25         4
#     accepted       0.67      0.67      0.67         9
#
#  avg / total       0.54      0.54      0.54        13
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.38      0.55         8
#     accepted       0.50      1.00      0.67         5
#
#  avg / total       0.81      0.62      0.59        13
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.43      0.55         7
#     accepted       0.50      0.80      0.62         5
#
#  avg / total       0.65      0.58      0.57        12
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.20      0.29         5
#     accepted       0.60      0.86      0.71         7
#
#  avg / total       0.56      0.58      0.53        12
#
# Medium clone is #9
# ('5NN', 0.6166666666666666, 0.12246106601291848, 0.6679563492063492, 0.12419421723041067, 0.7729116069116069, 0.13733628958211017, 0.03389334678649902)
# P=0.80 R=0.57 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.22      0.50      0.31         4
#     accepted       0.60      0.30      0.40        10
#
#  avg / total       0.49      0.36      0.37        14
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.50      0.44         4
#     accepted       0.78      0.70      0.74        10
#
#  avg / total       0.67      0.64      0.65        14
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.86      0.67      0.75         9
#
#  avg / total       0.75      0.69      0.70        13
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.20      0.25         5
#     accepted       0.60      0.75      0.67         8
#
#  avg / total       0.50      0.54      0.51        13
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.43      1.00      0.60         3
#     accepted       1.00      0.60      0.75        10
#
#  avg / total       0.87      0.69      0.72        13
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.89      0.89      0.89         9
#
#  avg / total       0.85      0.85      0.85        13
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.17      0.25         6
#     accepted       0.55      0.86      0.67         7
#
#  avg / total       0.52      0.54      0.47        13
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.43      0.60         7
#     accepted       0.60      1.00      0.75         6
#
#  avg / total       0.82      0.69      0.67        13
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.80      0.50      0.62         8
#     accepted       0.50      0.80      0.62         5
#
#  avg / total       0.68      0.62      0.62        13
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.20      0.25         5
#     accepted       0.60      0.75      0.67         8
#
#  avg / total       0.50      0.54      0.51        13
#
# Medium clone is #8
# ('5NN', 0.6153846153846153, 0.12498037522556397, 0.6657738095238095, 0.1317077854338541, 0.7678686082436084, 0.13053393018808515, 0.029920339584350586)
# P=1.00 R=0.40 thresh=0.80
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.22      0.50      0.31         4
#     accepted       0.60      0.30      0.40        10
#
#  avg / total       0.49      0.36      0.37        14
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         4
#     accepted       0.75      0.60      0.67        10
#
#  avg / total       0.63      0.57      0.59        14
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.60      0.55         5
#     accepted       0.75      0.67      0.71         9
#
#  avg / total       0.66      0.64      0.65        14
#
# Clone #3
#               precision    recall  f1-score   support
#
# ...
#
#  avg / total       0.62      0.59      0.58       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.51      0.81      0.62        80
#     accepted       0.79      0.47      0.59       120
#
#  avg / total       0.68      0.61      0.61       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.61      0.86      0.71       104
#     accepted       0.72      0.41      0.52        96
#
#  avg / total       0.66      0.64      0.62       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.76      0.87      0.81       138
#     accepted       0.57      0.39      0.46        62
#
#  avg / total       0.70      0.72      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.75      0.84       186
#     accepted       0.18      0.71      0.28        14
#
#  avg / total       0.92      0.74      0.81       200
#
# Medium clone is #0
# ('66NN', 0.6205, 0.04137934267240116, 0.6976705950332611, 0.044405459509446875, 0.7037905182780624, 0.10112783548020564, 0.4342021942138672)
# P=0.82 R=0.38 thresh=0.61
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.82      0.59        77
#     accepted       0.78      0.41      0.53       123
#
#  avg / total       0.66      0.56      0.56       200
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60        80
#     accepted       0.75      0.50      0.60       120
#
#  avg / total       0.65      0.60      0.60       200
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.91      0.62        75
#     accepted       0.88      0.39      0.54       125
#
#  avg / total       0.72      0.58      0.57       200
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.48      0.88      0.62        76
#     accepted       0.85      0.40      0.55       124
#
#  avg / total       0.71      0.58      0.57       200
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.83      0.60        89
#     accepted       0.66      0.26      0.37       111
#
#  avg / total       0.58      0.52      0.48       200
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.55      0.80      0.65        95
#     accepted       0.69      0.41      0.51       105
#
#  avg / total       0.63      0.59      0.58       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.51      0.82      0.63        80
#     accepted       0.80      0.47      0.60       120
#
#  avg / total       0.69      0.61      0.61       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.62      0.86      0.72       104
#     accepted       0.73      0.43      0.54        96
#
#  avg / total       0.67      0.65      0.63       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.76      0.86      0.81       138
#     accepted       0.56      0.39      0.46        62
#
#  avg / total       0.70      0.71      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.76      0.85       186
#     accepted       0.18      0.71      0.29        14
#
#  avg / total       0.92      0.76      0.81       200
#
# Medium clone is #0
# ('71NN', 0.6245, 0.03984030622372272, 0.6995961399989902, 0.048139054713202484, 0.7080071798529768, 0.09430952766327945, 0.4717395305633545)
# P=0.82 R=0.40 thresh=0.59
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.84      0.60        77
#     accepted       0.81      0.41      0.54       123
#
#  avg / total       0.68      0.57      0.57       200
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.51      0.76      0.61        80
#     accepted       0.76      0.51      0.61       120
#
#  avg / total       0.66      0.61      0.61       200
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.91      0.62        75
#     accepted       0.87      0.38      0.53       125
#
#  avg / total       0.72      0.57      0.56       200
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.87      0.61        76
#     accepted       0.83      0.40      0.54       124
#
#  avg / total       0.70      0.58      0.57       200
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.48      0.84      0.61        89
#     accepted       0.69      0.28      0.40       111
#
#  avg / total       0.60      0.53      0.49       200
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.55      0.80      0.65        95
#     accepted       0.69      0.40      0.51       105
#
#  avg / total       0.62      0.59      0.57       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.51      0.82      0.63        80
#     accepted       0.80      0.47      0.59       120
#
#  avg / total       0.68      0.61      0.61       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.62      0.86      0.72       104
#     accepted       0.73      0.43      0.54        96
#
#  avg / total       0.67      0.65      0.63       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.76      0.86      0.81       138
#     accepted       0.56      0.39      0.46        62
#
#  avg / total       0.70      0.71      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.76      0.86       186
#     accepted       0.19      0.71      0.29        14
#
#  avg / total       0.92      0.76      0.82       200
#
# Medium clone is #0
# ('76NN', 0.6255, 0.043843471577875756, 0.6987580046548623, 0.04633623257505498, 0.7093876872986111, 0.09504260723177609, 0.5470690727233887)
# P=0.81 R=0.41 thresh=0.58
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.83      0.60        77
#     accepted       0.79      0.41      0.54       123
#
#  avg / total       0.67      0.57      0.56       200
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60        80
#     accepted       0.75      0.50      0.60       120
#
#  avg / total       0.65      0.60      0.60       200
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.91      0.62        75
#     accepted       0.87      0.38      0.53       125
#
#  avg / total       0.72      0.57      0.56       200
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.87      0.60        76
#     accepted       0.82      0.38      0.52       124
#
#  avg / total       0.69      0.56      0.55       200
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.49      0.87      0.63        89
#     accepted       0.72      0.28      0.40       111
#
#  avg / total       0.62      0.54      0.50       200
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.54      0.79      0.64        95
#     accepted       0.67      0.39      0.49       105
#
#  avg / total       0.61      0.58      0.56       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.52      0.81      0.63        80
#     accepted       0.80      0.50      0.62       120
#
#  avg / total       0.69      0.62      0.62       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.61      0.86      0.71       104
#     accepted       0.73      0.42      0.53        96
#
#  avg / total       0.67      0.65      0.63       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.76      0.88      0.81       138
#     accepted       0.57      0.37      0.45        62
#
#  avg / total       0.70      0.72      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.76      0.85       186
#     accepted       0.18      0.71      0.29        14
#
#  avg / total       0.92      0.76      0.81       200
#
# Medium clone is #0
# ('81NN', 0.6295, 0.04021504693519578, 0.69813700741392, 0.04698476903525236, 0.7084605981633808, 0.09344925394402823, 0.5631160736083984)
# P=0.80 R=0.39 thresh=0.60
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.81      0.58        77
#     accepted       0.77      0.41      0.53       123
#
#  avg / total       0.65      0.56      0.55       200
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.74      0.59        80
#     accepted       0.74      0.50      0.60       120
#
#  avg / total       0.64      0.59      0.60       200
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.91      0.61        75
#     accepted       0.87      0.37      0.52       125
#
#  avg / total       0.72      0.57      0.55       200
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.87      0.61        76
#     accepted       0.83      0.39      0.53       124
#
#  avg / total       0.69      0.57      0.56       200
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.82      0.60        89
#     accepted       0.65      0.27      0.38       111
#
#  avg / total       0.57      0.52      0.48       200
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.54      0.80      0.65        95
#     accepted       0.68      0.39      0.50       105
#
#  avg / total       0.62      0.58      0.57       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.51      0.82      0.63        80
#     accepted       0.80      0.47      0.59       120
#
#  avg / total       0.68      0.61      0.61       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.61      0.86      0.71       104
#     accepted       0.73      0.42      0.53        96
#
#  avg / total       0.67      0.65      0.63       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.87      0.81       138
#     accepted       0.56      0.37      0.45        62
#
#  avg / total       0.69      0.71      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.78      0.87       186
#     accepted       0.20      0.71      0.31        14
#
#  avg / total       0.92      0.78      0.83       200
#
# Medium clone is #0
# ('86NN', 0.6260000000000001, 0.040174618853201324, 0.6947266814270846, 0.04626047083115823, 0.7064690641962411, 0.09270673174275385, 0.5694890022277832)
# P=0.80 R=0.39 thresh=0.59
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.45      0.81      0.58        77
#     accepted       0.76      0.39      0.52       123
#
#  avg / total       0.64      0.55      0.54       200
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60        80
#     accepted       0.75      0.51      0.61       120
#
#  avg / total       0.65      0.60      0.61       200
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.91      0.61        75
#     accepted       0.87      0.37      0.52       125
#
#  avg / total       0.72      0.57      0.55       200
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.89      0.62        76
#     accepted       0.86      0.39      0.53       124
#
#  avg / total       0.71      0.58      0.57       200
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.48      0.83      0.61        89
#     accepted       0.67      0.27      0.38       111
#
#  avg / total       0.58      0.52      0.48       200
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.53      0.79      0.64        95
#     accepted       0.66      0.37      0.48       105
#
#  avg / total       0.60      0.57      0.55       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.82      0.63        80
#     accepted       0.80      0.46      0.58       120
#
#  avg / total       0.68      0.60      0.60       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.61      0.87      0.72       104
#     accepted       0.74      0.41      0.52        96
#
#  avg / total       0.67      0.65      0.62       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.87      0.81       138
#     accepted       0.56      0.37      0.45        62
#
#  avg / total       0.69      0.71      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.77      0.86       186
#     accepted       0.19      0.71      0.30        14
#
#  avg / total       0.92      0.77      0.82       200
#
# Medium clone is #0
# ('91NN', 0.6305000000000001, 0.03875886995256698, 0.6945497929935459, 0.046871972379409835, 0.7082945559958551, 0.09230054638047064, 0.6193945407867432)
# P=0.83 R=0.37 thresh=0.62
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.46      0.82      0.59        77
#     accepted       0.77      0.39      0.52       123
#
#  avg / total       0.65      0.56      0.54       200
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60        80
#     accepted       0.75      0.49      0.59       120
#
#  avg / total       0.65      0.59      0.59       200
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.92      0.62        75
#     accepted       0.89      0.38      0.53       125
#
#  avg / total       0.73      0.58      0.56       200
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.48      0.89      0.62        76
#     accepted       0.86      0.40      0.54       124
#
#  avg / total       0.71      0.58      0.57       200
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.47      0.84      0.61        89
#     accepted       0.67      0.25      0.37       111
#
#  avg / total       0.58      0.52      0.47       200
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.54      0.80      0.64        95
#     accepted       0.67      0.37      0.48       105
#
#  avg / total       0.61      0.57      0.56       200
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.82      0.63        80
#     accepted       0.80      0.46      0.58       120
#
#  avg / total       0.68      0.60      0.60       200
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.61      0.86      0.71       104
#     accepted       0.72      0.41      0.52        96
#
#  avg / total       0.66      0.64      0.62       200
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.87      0.81       138
#     accepted       0.56      0.37      0.45        62
#
#  avg / total       0.69      0.71      0.70       200
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.97      0.78      0.87       186
#     accepted       0.20      0.71      0.31        14
#
#  avg / total       0.92      0.78      0.83       200
#
# Medium clone is #0
# ('96NN', 0.623, 0.04160528812542943, 0.6941884411326166, 0.046210109468366456, 0.7109463405049815, 0.0924908287855318, 0.8620002269744873)
# P=0.82 R=0.37 thresh=0.60

# %%
from sklearn.linear_model import LogisticRegression
for C in [0.1]:
# for C in [0.01, 0.1, 1.0, 10.0]:
    name = "LogReg C=%.2f" % C
    bias_variance_analysis(LogisticRegression, {'penalty': 'l2', 'C': C}, name)
    measure(LogisticRegression, {'penalty': 'l2', 'C': C}, name, plot=True)

print("=" * 50)
from operator import itemgetter
for s in reversed(sorted(avg_scores_summary, key=itemgetter(1))):
    print("%-20s\t%.5f\t%.5f\t%.5f\t%.5f\t%.5f\t%.5f\t%.5f" % s)

print("time spent:", time.time() - start_time)
# Out:
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.75      0.75      0.75         4
#
#  avg / total       0.67      0.67      0.67         6
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.56      0.50      0.51         6
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         1
#     accepted       1.00      0.60      0.75         5
#
#  avg / total       0.89      0.67      0.71         6
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.50      0.33      0.40         3
#
#  avg / total       0.50      0.50      0.49         6
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.67      0.67      0.67         6
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         1
#     accepted       1.00      0.60      0.75         5
#
#  avg / total       0.89      0.67      0.71         6
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         3
#     accepted       0.75      1.00      0.86         3
#
#  avg / total       0.88      0.83      0.83         6
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.69      0.83      0.76         6
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.50      0.67      0.57         3
#
#  avg / total       0.50      0.50      0.49         6
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.69      0.83      0.76         6
#
# Medium clone is #4
# ('LogReg C=0.10', 0.7333333333333332, 0.16996731711975951, 0.8322222222222223, 0.13759508496820447, 0.913638888888889, 0.09212940442927996, 0.02892446517944336)
# P=0.83 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.75      0.75      0.75         4
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.67      0.33      0.44         6
#
#  avg / total       0.57      0.29      0.38         7
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.67      1.00      0.80         2
#     accepted       1.00      0.80      0.89         5
#
#  avg / total       0.90      0.86      0.86         7
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         2
#     accepted       0.50      0.25      0.33         4
#
#  avg / total       0.42      0.33      0.33         6
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.80      1.00      0.89         4
#
#  avg / total       0.87      0.83      0.81         6
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.83      1.00      0.91         5
#
#  avg / total       0.69      0.83      0.76         6
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.60      0.75      0.67         4
#
#  avg / total       0.40      0.50      0.44         6
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.50      1.00      0.67         3
#
#  avg / total       0.25      0.50      0.33         6
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.75      0.75      0.75         4
#
#  avg / total       0.67      0.67      0.67         6
#
# Medium clone is #9
# ('LogReg C=0.10', 0.6690476190476191, 0.16442368257732903, 0.7338888888888888, 0.21490307892939398, 0.8936984126984127, 0.0835725450829109, 0.022937774658203125)
# P=1.00 R=0.75 thresh=0.66
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.60      0.75      0.67         4
#
#  avg / total       0.56      0.57      0.55         7
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.67      0.33      0.44         6
#
#  avg / total       0.57      0.29      0.38         7
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.67      1.00      0.80         2
#     accepted       1.00      0.80      0.89         5
#
#  avg / total       0.90      0.86      0.86         7
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         2
#     accepted       1.00      0.20      0.33         5
#
#  avg / total       0.81      0.43      0.38         7
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.57      1.00      0.73         4
#
#  avg / total       0.33      0.57      0.42         7
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         1
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.73      0.86      0.79         7
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.57      1.00      0.73         4
#
#  avg / total       0.33      0.57      0.42         7
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         4
#
#  avg / total       1.00      1.00      1.00         6
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.50      0.29         2
#     accepted       0.00      0.00      0.00         4
#
#  avg / total       0.07      0.17      0.10         6
#
# Medium clone is #2
# ('LogReg C=0.10', 0.5738095238095238, 0.14771502256424854, 0.7116666666666667, 0.24506801776921716, 0.8676269841269841, 0.14042923790482023, 0.022939205169677734)
# P=0.80 R=0.80 thresh=0.52
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.17      1.00      0.29         1
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.90      0.38      0.42         8
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.60      0.57      0.57         7
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.71      0.71      0.71         7
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         2
#     accepted       1.00      0.40      0.57         5
#
#  avg / total       0.83      0.57      0.57         7
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.51      0.71      0.60         7
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.51      0.71      0.60         7
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         3
#     accepted       0.57      1.00      0.73         4
#
#  avg / total       0.33      0.57      0.42         7
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.67      1.00      0.80         2
#     accepted       1.00      0.80      0.89         5
#
#  avg / total       0.90      0.86      0.86         7
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.75      0.60      0.67         5
#
#  avg / total       0.63      0.57      0.59         7
#
# Medium clone is #5
# ('LogReg C=0.10', 0.6678571428571429, 0.059333027592271985, 0.7169047619047619, 0.21528984312616328, 0.8822151360544217, 0.09792049672237882, 0.02594447135925293)
# P=0.80 R=0.80 thresh=0.69
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.17      1.00      0.29         1
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.90      0.38      0.42         8
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.75      0.67         4
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.63      0.62      0.62         8
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         2
#     accepted       0.75      0.50      0.60         6
#
#  avg / total       0.62      0.50      0.53         8
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.67      1.00      0.80         4
#
#  avg / total       0.81      0.71      0.67         7
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         2
#     accepted       1.00      1.00      1.00         5
#
#  avg / total       1.00      1.00      1.00         7
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.50      0.29         2
#     accepted       0.50      0.20      0.29         5
#
#  avg / total       0.41      0.29      0.29         7
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.51      0.71      0.60         7
#
# Medium clone is #6
# ('LogReg C=0.10', 0.6303571428571428, 0.1290294421392866, 0.7160714285714286, 0.27099759539895946, 0.8704571995464854, 0.14041689606641058, 0.024937868118286133)
# P=0.80 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.80      0.80      0.80         5
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.17      1.00      0.29         1
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.90      0.38      0.42         8
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.75      0.67         4
#     accepted       0.67      0.50      0.57         4
#
#  avg / total       0.63      0.62      0.62         8
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.75      0.75      0.75         8
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         2
#     accepted       0.75      0.50      0.60         6
#
#  avg / total       0.62      0.50      0.53         8
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.82      0.75      0.71         8
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.75      1.00      0.86         3
#     accepted       1.00      0.80      0.89         5
#
#  avg / total       0.91      0.88      0.88         8
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.80      0.67      0.73         6
#
#  avg / total       0.68      0.62      0.65         8
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.89      0.88      0.86         8
#
# Medium clone is #0
# ('LogReg C=0.10', 0.6625, 0.09762812094883318, 0.7177380952380952, 0.23074760804129704, 0.8813401360544215, 0.10125121481035827, 0.02488875389099121)
# P=0.80 R=0.80 thresh=0.54
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.78      0.78      0.78         9
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         2
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.85      0.56      0.58         9
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.80      0.67      0.73         6
#
#  avg / total       0.70      0.67      0.68         9
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         2
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.85      0.56      0.58         9
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.82      0.75      0.71         8
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.67      0.80      0.73         5
#
#  avg / total       0.60      0.62      0.60         8
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.33      0.29         3
#     accepted       0.50      0.40      0.44         5
#
#  avg / total       0.41      0.38      0.38         8
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.56      0.75      0.64         8
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.50      0.50         2
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.75      0.75      0.75         8
#
# Medium clone is #0
# ('LogReg C=0.10', 0.6319444444444444, 0.11838190187422243, 0.7524603174603175, 0.16346488061894887, 0.8932304421768708, 0.09342008529832695, 0.021939516067504883)
# P=0.83 R=0.83 thresh=0.54
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.80      0.67      0.73         6
#
#  avg / total       0.70      0.67      0.68         9
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.84      0.44      0.44         9
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.80      0.67      0.73         6
#
#  avg / total       0.70      0.67      0.68         9
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         2
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.85      0.56      0.58         9
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.75      1.00      0.86         6
#
#  avg / total       0.83      0.78      0.74         9
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         4
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.84      0.78      0.76         9
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.75      1.00      0.86         3
#     accepted       1.00      0.83      0.91         6
#
#  avg / total       0.92      0.89      0.89         9
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.50      0.33         2
#     accepted       0.80      0.57      0.67         7
#
#  avg / total       0.68      0.56      0.59         9
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.89      0.88      0.86         8
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.67      0.80      0.73         5
#
#  avg / total       0.60      0.62      0.60         8
#
# Medium clone is #1
# ('LogReg C=0.10', 0.6277777777777779, 0.09229582069908972, 0.7636507936507937, 0.16269872241550082, 0.8969396258503401, 0.06801268160282249, 0.023935317993164062)
# P=0.86 R=0.86 thresh=0.42
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.80      0.57      0.67         7
#
#  avg / total       0.68      0.60      0.62        10
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.38      1.00      0.55         3
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.81      0.50      0.47        10
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.64      0.67      0.65         9
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.29      0.44         7
#
#  avg / total       0.84      0.44      0.44         9
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.75      0.86      0.80         7
#
#  avg / total       0.58      0.67      0.62         9
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         4
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.84      0.78      0.76         9
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.75      1.00      0.86         3
#     accepted       1.00      0.83      0.91         6
#
#  avg / total       0.92      0.89      0.89         9
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.50      0.40         2
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.72      0.67      0.69         9
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.88      1.00      0.93         7
#
#  avg / total       0.90      0.89      0.87         9
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.20      0.33         5
#     accepted       0.50      1.00      0.67         4
#
#  avg / total       0.78      0.56      0.48         9
#
# Medium clone is #5
# ('LogReg C=0.10', 0.6100000000000001, 0.12297244497131145, 0.7169841269841271, 0.18296024705663097, 0.8561465419501134, 0.16383245504677055, 0.023980140686035156)
# P=0.80 R=0.80 thresh=0.75
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.73      0.70      0.71        10
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         3
#     accepted       1.00      0.14      0.25         7
#
#  avg / total       0.80      0.40      0.33        10
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.73      0.70      0.71        10
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.67      0.44         3
#     accepted       0.75      0.43      0.55         7
#
#  avg / total       0.62      0.50      0.52        10
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.78      0.88      0.82         8
#
#  avg / total       0.62      0.70      0.66        10
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.50      0.57         4
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.70      0.70      0.69        10
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.80      0.67      0.73         6
#
#  avg / total       0.70      0.67      0.68         9
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         3
#     accepted       0.86      1.00      0.92         6
#
#  avg / total       0.90      0.89      0.88         9
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.67      1.00      0.80         2
#     accepted       1.00      0.86      0.92         7
#
#  avg / total       0.93      0.89      0.90         9
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         6
#     accepted       0.33      1.00      0.50         3
#
#  avg / total       0.11      0.33      0.17         9
#
# Medium clone is #2
# ('LogReg C=0.10', 0.5922222222222222, 0.13833668001306462, 0.7107142857142856, 0.15726706651146224, 0.848407029478458, 0.12930189490989907, 0.025213003158569336)
# P=0.83 R=0.71 thresh=0.56
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.67      0.44         3
#     accepted       0.75      0.43      0.55         7
#
#  avg / total       0.62      0.50      0.52        10
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         3
#     accepted       1.00      0.14      0.25         7
#
#  avg / total       0.80      0.40      0.33        10
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.73      0.70      0.71        10
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.43      1.00      0.60         3
#     accepted       1.00      0.43      0.60         7
#
#  avg / total       0.83      0.60      0.60        10
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.78      0.88      0.82         8
#
#  avg / total       0.62      0.70      0.66        10
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.50      0.57         4
#     accepted       0.71      0.83      0.77         6
#
#  avg / total       0.70      0.70      0.69        10
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.83      0.71      0.77         7
#
#  avg / total       0.73      0.70      0.71        10
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.78      1.00      0.88         7
#
#  avg / total       0.84      0.80      0.76        10
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.80      0.80      0.80        10
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         7
#     accepted       0.22      0.67      0.33         3
#
#  avg / total       0.07      0.20      0.10        10
#
# Medium clone is #8
# ('LogReg C=0.10', 0.6099999999999999, 0.14456832294800961, 0.6988095238095238, 0.1494794444343102, 0.8365650982615268, 0.12541033655521888, 0.028553247451782227)
# P=0.83 R=0.83 thresh=0.57
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.67      0.44         3
#     accepted       0.80      0.50      0.62         8
#
#  avg / total       0.67      0.55      0.57        11
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.38      0.75      0.50         4
#     accepted       0.67      0.29      0.40         7
#
#  avg / total       0.56      0.45      0.44        11
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.50      1.00      0.67         3
#     accepted       1.00      0.62      0.77         8
#
#  avg / total       0.86      0.73      0.74        11
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.25      0.33      0.29         3
#     accepted       0.71      0.62      0.67         8
#
#  avg / total       0.59      0.55      0.56        11
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.25      0.40         4
#     accepted       0.67      1.00      0.80         6
#
#  avg / total       0.80      0.70      0.64        10
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       1.00      1.00      1.00         3
#     accepted       1.00      1.00      1.00         7
#
#  avg / total       1.00      1.00      1.00        10
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.00      0.00      0.00         2
#     accepted       0.78      0.88      0.82         8
#
#  avg / total       0.62      0.70      0.66        10
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         3
#     accepted       0.88      1.00      0.93         7
#
#  avg / total       0.91      0.90      0.89        10
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.33      0.44         6
#     accepted       0.43      0.75      0.55         4
#
#  avg / total       0.57      0.50      0.48        10
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.40      0.40         5
#     accepted       0.40      0.40      0.40         5
#
#  avg / total       0.40      0.40      0.40        10
#
# Medium clone is #6
# ('LogReg C=0.10', 0.6254545454545454, 0.09848438228327885, 0.7086190476190477, 0.1877744340831256, 0.8187507730364872, 0.19128421950991278, 0.023990392684936523)
# P=0.80 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.29      0.67      0.40         3
#     accepted       0.75      0.38      0.50         8
#
#  avg / total       0.62      0.45      0.47        11
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.38      0.75      0.50         4
#     accepted       0.67      0.29      0.40         7
#
#  avg / total       0.56      0.45      0.44        11
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.43      1.00      0.60         3
#     accepted       1.00      0.50      0.67         8
#
#  avg / total       0.84      0.64      0.65        11
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.67      0.50         3
#     accepted       0.83      0.62      0.71         8
#
#  avg / total       0.72      0.64      0.66        11
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.25      0.40         4
#     accepted       0.70      1.00      0.82         7
#
#  avg / total       0.81      0.73      0.67        11
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      1.00      0.67         3
#     accepted       1.00      0.62      0.77         8
#
#  avg / total       0.86      0.73      0.74        11
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.25      0.40         4
#     accepted       0.70      1.00      0.82         7
#
#  avg / total       0.81      0.73      0.67        11
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.82      0.82      0.82        11
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         6
#     accepted       0.33      0.50      0.40         4
#
#  avg / total       0.43      0.40      0.40        10
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.40      0.44         5
#     accepted       0.50      0.60      0.55         5
#
#  avg / total       0.50      0.50      0.49        10
#
# Medium clone is #3
# ('LogReg C=0.10', 0.58, 0.125625706691816, 0.6762380952380953, 0.14535599430145657, 0.8183122358792001, 0.13772937371865454, 0.02501988410949707)
# P=0.83 R=0.62 thresh=0.55
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.75      0.46         4
#     accepted       0.67      0.25      0.36         8
#
#  avg / total       0.56      0.42      0.40        12
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.75      0.46         4
#     accepted       0.67      0.25      0.36         8
#
#  avg / total       0.56      0.42      0.40        12
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.44      0.62         9
#
#  avg / total       0.87      0.55      0.58        11
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.67      0.67         3
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.82      0.82      0.82        11
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.25      0.33         4
#     accepted       0.67      0.86      0.75         7
#
#  avg / total       0.61      0.64      0.60        11
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.80      0.57      0.67         7
#
#  avg / total       0.69      0.64      0.64        11
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.33      0.50         3
#     accepted       0.80      1.00      0.89         8
#
#  avg / total       0.85      0.82      0.78        11
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.86      0.86      0.86         7
#
#  avg / total       0.82      0.82      0.82        11
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.29      0.36         7
#     accepted       0.29      0.50      0.36         4
#
#  avg / total       0.42      0.36      0.36        11
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.67      0.33      0.44         6
#     accepted       0.50      0.80      0.62         5
#
#  avg / total       0.59      0.55      0.52        11
#
# Medium clone is #7
# ('LogReg C=0.10', 0.5962121212121211, 0.13398814757828417, 0.6606150793650793, 0.17196467031444793, 0.7696296797338464, 0.18153773686937327, 0.021986722946166992)
# P=0.88 R=1.00 thresh=0.00
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         4
#     accepted       1.00      0.25      0.40         8
#
#  avg / total       0.80      0.50      0.46        12
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.75      0.46         4
#     accepted       0.67      0.25      0.36         8
#
#  avg / total       0.56      0.42      0.40        12
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.50      0.67        10
#
#  avg / total       0.88      0.58      0.63        12
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.83      0.83      0.83        12
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.50      0.44         4
#     accepted       0.71      0.62      0.67         8
#
#  avg / total       0.61      0.58      0.59        12
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.83      0.62      0.71         8
#
#  avg / total       0.72      0.67      0.68        12
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.50      0.67         2
#     accepted       0.90      1.00      0.95         9
#
#  avg / total       0.92      0.91      0.90        11
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.43      0.55         7
#     accepted       0.43      0.75      0.55         4
#
#  avg / total       0.63      0.55      0.55        11
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.33      0.36         6
#     accepted       0.33      0.40      0.36         5
#
#  avg / total       0.37      0.36      0.36        11
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         6
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.87      0.82      0.82        11
#
# Medium clone is #0
# ('LogReg C=0.10', 0.6007575757575758, 0.15136545635451462, 0.6742261904761905, 0.1655432589332205, 0.7464776334776335, 0.20041785689248828, 0.021924257278442383)
# P=1.00 R=0.25 thresh=0.59
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         4
#     accepted       1.00      0.25      0.40         8
#
#  avg / total       0.80      0.50      0.46        12
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.75      0.46         4
#     accepted       0.67      0.25      0.36         8
#
#  avg / total       0.56      0.42      0.40        12
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.29      1.00      0.44         2
#     accepted       1.00      0.50      0.67        10
#
#  avg / total       0.88      0.58      0.63        12
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.83      0.83      0.83        12
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.50      0.44         4
#     accepted       0.71      0.62      0.67         8
#
#  avg / total       0.61      0.58      0.59        12
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.75      0.60         4
#     accepted       0.83      0.62      0.71         8
#
#  avg / total       0.72      0.67      0.68        12
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.67      0.80         3
#     accepted       0.90      1.00      0.95         9
#
#  avg / total       0.92      0.92      0.91        12
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.43      0.55         7
#     accepted       0.50      0.80      0.62         5
#
#  avg / total       0.65      0.58      0.57        12
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.40      0.33      0.36         6
#     accepted       0.43      0.50      0.46         6
#
#  avg / total       0.41      0.42      0.41        12
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.83      0.71      0.77         7
#     accepted       0.67      0.80      0.73         5
#
#  avg / total       0.76      0.75      0.75        12
#
# Medium clone is #0
# ('LogReg C=0.10', 0.6000000000000001, 0.11666666666666667, 0.6843816137566138, 0.1614970473096491, 0.7754878747795415, 0.16247888688887346, 0.022934436798095703)
# P=1.00 R=0.25 thresh=0.59
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.36      1.00      0.53         4
#     accepted       1.00      0.22      0.36         9
#
#  avg / total       0.80      0.46      0.42        13
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.33      0.75      0.46         4
#     accepted       0.75      0.33      0.46         9
#
#  avg / total       0.62      0.46      0.46        13
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         4
#     accepted       1.00      0.33      0.50         9
#
#  avg / total       0.82      0.54      0.52        13
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.89      0.80      0.84        10
#
#  avg / total       0.80      0.77      0.78        13
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.60      0.55         5
#     accepted       0.67      0.57      0.62         7
#
#  avg / total       0.60      0.58      0.59        12
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.33      0.40         3
#     accepted       0.80      0.89      0.84         9
#
#  avg / total       0.72      0.75      0.73        12
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.75      0.75         4
#     accepted       0.88      0.88      0.88         8
#
#  avg / total       0.83      0.83      0.83        12
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.25      0.33         8
#     accepted       0.25      0.50      0.33         4
#
#  avg / total       0.42      0.33      0.33        12
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.50      0.55         6
#     accepted       0.57      0.67      0.62         6
#
#  avg / total       0.59      0.58      0.58        12
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.83      0.83      0.83         6
#     accepted       0.83      0.83      0.83         6
#
#  avg / total       0.83      0.83      0.83        12
#
# Medium clone is #0
# ('LogReg C=0.10', 0.5878205128205128, 0.18259781631951363, 0.6192824074074074, 0.1329986334883696, 0.7585269564540398, 0.11447564061452957, 0.023908376693725586)
# P=0.80 R=0.89 thresh=0.48
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.36      1.00      0.53         4
#     accepted       1.00      0.22      0.36         9
#
#  avg / total       0.80      0.46      0.42        13
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.38      0.75      0.50         4
#     accepted       0.80      0.44      0.57         9
#
#  avg / total       0.67      0.54      0.55        13
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         4
#     accepted       1.00      0.33      0.50         9
#
#  avg / total       0.82      0.54      0.52        13
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.67      0.57         3
#     accepted       0.89      0.80      0.84        10
#
#  avg / total       0.80      0.77      0.78        13
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.43      0.60      0.50         5
#     accepted       0.67      0.50      0.57         8
#
#  avg / total       0.58      0.54      0.54        13
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.50      0.25      0.33         4
#     accepted       0.73      0.89      0.80         9
#
#  avg / total       0.66      0.69      0.66        13
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.75      0.67         4
#     accepted       0.88      0.78      0.82         9
#
#  avg / total       0.79      0.77      0.78        13
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.38      0.46         8
#     accepted       0.38      0.60      0.46         5
#
#  avg / total       0.51      0.46      0.46        13
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.57      0.73         7
#     accepted       0.62      1.00      0.77         5
#
#  avg / total       0.84      0.75      0.74        12
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.60      0.60         5
#     accepted       0.71      0.71      0.71         7
#
#  avg / total       0.67      0.67      0.67        12
#
# Medium clone is #4
# ('LogReg C=0.10', 0.576923076923077, 0.188966704781842, 0.6065476190476191, 0.12168005522788865, 0.7430812706913896, 0.1272373138448975, 0.02839183807373047)
# P=0.80 R=0.50 thresh=0.59
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         4
#     accepted       1.00      0.20      0.33        10
#
#  avg / total       0.81      0.43      0.38        14
#
# Clone #1
#               precision    recall  f1-score   support
#
# not accepted       0.38      0.75      0.50         4
#     accepted       0.83      0.50      0.62        10
#
#  avg / total       0.70      0.57      0.59        14
#
# Clone #2
#               precision    recall  f1-score   support
#
# not accepted       0.40      1.00      0.57         4
#     accepted       1.00      0.33      0.50         9
#
#  avg / total       0.82      0.54      0.52        13
#
# Clone #3
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.60      0.67         5
#     accepted       0.78      0.88      0.82         8
#
#  avg / total       0.77      0.77      0.76        13
#
# Clone #4
#               precision    recall  f1-score   support
#
# not accepted       0.38      1.00      0.55         3
#     accepted       1.00      0.50      0.67        10
#
#  avg / total       0.86      0.62      0.64        13
#
# Clone #5
#               precision    recall  f1-score   support
#
# not accepted       0.20      0.25      0.22         4
#     accepted       0.62      0.56      0.59         9
#
#  avg / total       0.49      0.46      0.48        13
#
# Clone #6
#               precision    recall  f1-score   support
#
# not accepted       0.75      0.50      0.60         6
#     accepted       0.67      0.86      0.75         7
#
#  avg / total       0.71      0.69      0.68        13
#
# Clone #7
#               precision    recall  f1-score   support
#
# not accepted       0.60      0.43      0.50         7
#     accepted       0.50      0.67      0.57         6
#
#  avg / total       0.55      0.54      0.53        13
#
# Clone #8
#               precision    recall  f1-score   support
#
# not accepted       1.00      0.75      0.86         8
#     accepted       0.71      1.00      0.83         5
#
#  avg / total       0.89      0.85      0.85        13
#
# Clone #9
#               precision    recall  f1-score   support
#
# not accepted       0.43      0.60      0.50         5
#     accepted       0.67      0.50      0.57         8
#
#  avg / total       0.58      0.54      0.54        13
#
# Medium clone is #5
# ('LogReg C=0.10', 0.5593406593406594, 0.15735404237071426, 0.6109523809523809, 0.13835750956675513, 0.7556336498598403, 0.11062100558208385, 0.020952939987182617)
# P=0.83 R=0.56 thresh=0.66
# Clone #0
#               precision    recall  f1-score   support
#
# not accepted       0.33      1.00      0.50         4
#     accepted       1.00      0.20      0.33        10
#
#  avg / total       0.81      0.43      0.38        14
#
